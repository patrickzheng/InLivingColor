# %% [markdown]
# History Server: http://52.8.132.94:18088/

# %% [markdown]
# # Load Spark

# %%
import os
import sys


spark_home = os.environ.get('SPARK_HOME', None)
if not spark_home:
    raise ValueError('SPARK_HOME environment variable is not set')
sys.path.insert(0, os.path.join(spark_home, 'python'))
sys.path.insert(0, os.path.join(spark_home, 'python/lib/py4j-0.8.2.1-src.zip'))

# %%
# PYSPARK_SUBMIT_ARGS = os.environ.get('PYSPARK_SUBMIT_ARGS', None) + """
#     --packages TargetHolding/pyspark-cassandra:0.1.5 \
#     --conf spark.cassandra.connection.host=172.31.0.16,172.31.9.80,172.31.9.81,172.31.9.82,172.31.9.83,172.31.9.84,172.31.9.85,172.31.9.86,172.31.9.87,172.31.9.88
# """
# os.environ['PYSPARK_SUBMIT_ARGS'] = PYSPARK_SUBMIT_ARGS
# print PYSPARK_SUBMIT_ARGS

# %%
execfile(os.path.join(spark_home, 'python/pyspark/shell.py'))
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 1.3.0
#       /_/
#
# Using Python version 2.7.9 (default, Mar  9 2015 16:20:48)
# SparkContext available as sc, HiveContext available as sqlCtx.

# %% [markdown]
# ## Take aggregated metaplus.json files and create counts

# %%
from _configuration import *
from batch_helper import timeoflastrun
import time
import json


# def IsInLocation(d,form,entity):
#     try:
#         return d['info']['location'][form]['_content'] == entity
#     except:
#         return '_'

def LocationLevel(d,form):
    try:
        output = d['info']['location'][form]['_content']
        assert type(output) == unicode or type(output) == str
        return output
    except:
        return '_'
# Out:
# Using flickr API_KEY:  ea199 ...
# Using AWS_ACCESS_KEY_ID:  AKIAJ ...

# %%
# Load the metaplus.json files for now-minus-4 hours till now
startprocessinghere = timeoflastrun("preparecountstest", set_to_now=False) - 3600*4
datetimebins = ALLBINSFROMTHISTIMETILONEHOURAGO(startprocessinghere)
# Out:
# First time running batch script. Returning the epoch.

# %%
rdd = sc.textFile(os.path.join(S3_PREFIX,'metaplus_%s.json'%(datetimebins[0]))).map(lambda s: json.loads(s))

# %%
rdd = rdd.flatMap(lambda d: (
        ######MONTHLY########
            ((('country',LocationLevel(d, 'country')),
                          ('region',LocationLevel(d, 'region')),
                          ('county',LocationLevel(d, 'county')),
                          ('locality',LocationLevel(d, 'locality')),
                          ('datetaken',str(d['info']['dates']['taken'][:7])),
                          ('granularity','locality/month'),
                         ),1),

            ((('country',LocationLevel(d, 'country')),
                          ('region',LocationLevel(d, 'region')),
                          ('county',LocationLevel(d, 'county')),
                          ('locality','*'),
                          ('datetaken',str(d['info']['dates']['taken'][:7])),
                          ('granularity','county/month'),
                         ),1),

            ((('country',LocationLevel(d, 'country')),
                          ('region',LocationLevel(d, 'region')),
                          ('county','*'),
                          ('locality','*'),
                          ('datetaken',str(d['info']['dates']['taken'][:7])),
                          ('granularity','region/month'),
                         ),1),

            ((('country',LocationLevel(d, 'country')),
                          ('region','*'),
                          ('county','*'),
                          ('locality','*'),
                          ('datetaken',str(d['info']['dates']['taken'][:7])),
                          ('granularity','country/month'),
                         ),1),

            ((('country','*'),
                          ('region','*'),
                          ('county','*'),
                          ('locality','*'),
                          ('datetaken',str(d['info']['dates']['taken'][:7])),
                          ('granularity','all/month'),
                         ),1),))

# %%
rdd.take(1)
# Out:
# [{u'clusters': {u'1': {u'centroids': {u'1': [0.3978965277777778,
#       0.5158647569444444,
#       0.6836331597222223]},
#     u'probs': {u'1': 1.0}},
#    u'2': {u'centroids': {u'1': [0.524786900829022,
#       0.6841338025151156,
#       0.9094946978432962],
#      u'2': [0.08262592922409788, 0.09778510724794796, 0.12245975782096949]},
#     u'probs': {u'1': 0.7130222222222222, u'2': 0.2869777777777778}},
#    u'3': {u'centroids': {u'1': [0.5268183597533415,
#       0.6918531974397882,
#       0.9249224147672241],
#      u'2': [0.011738822330205541, 0.01544522173815907, 0.022811766923592495],
#      u'3': [0.29219273502167914, 0.3244358494284588, 0.37657358592826173]},
#     u'probs': {u'1': 0.6883111111111111,
#      u'2': 0.19893333333333332,
#      u'3': 0.11275555555555555}},
#    u'4': {u'centroids': {u'1': [0.6102695244551315,
#       0.7503449395016883,
#       0.9408406771206385],
#      u'2': [0.3841218651695211, 0.5916808207357567, 0.897306994931842],
#      u'3': [0.01168033359409924, 0.015374420261510952, 0.02273116199150648],
#      u'4': [0.2917047362702489, 0.3237665448439352, 0.3756698192414066]},
#     u'probs': {u'1': 0.43435555555555555,
#      u'2': 0.2543111111111111,
#      u'3': 0.19884444444444443,
#      u'4': 0.11248888888888889}},
#    u'5': {u'centroids': {u'1': [0.6102695244551315,
#       0.7503449395016883,
#       0.9408406771206385],
#      u'2': [0.3841218651695211, 0.5916808207357567, 0.897306994931842],
#      u'3': [0.01168033359409924, 0.015374420261510952, 0.02273116199150648],
#      u'4': [0.2917047362702489, 0.3237665448439352, 0.3756698192414066],
#      u'5': [1.1339792425803976, 1.3852500163233112, 1.782714887264565]},
#     u'probs': {u'1': 0.43435555555555555,
#      u'2': 0.2543111111111111,
#      u'3': 0.19884444444444443,
#      u'4': 0.11248888888888889,
#      u'5': 0.0}},
#    u'6': {u'centroids': {u'1': [0.5168235273343693,
#       0.6879309621768611,
#       0.9328868837406413],
#      u'2': [0.674153974974722, 0.7920642694641051, 0.9504447358442871],
#      u'3': [0.00684692039597001, 0.009057228209934395, 0.014486439784442362],
#      u'4': [0.3274015340739636, 0.5549647703549061, 0.8820587440351924],
#      u'5': [0.1885054548816568, 0.23942538831360946, 0.31330436390532546],
#      u'6': [0.44189914163090127, 0.4431364002145923, 0.4541074302575107]},
#     u'probs': {u'1': 0.31462222222222225,
#      u'2': 0.21977777777777777,
#      u'3': 0.18968888888888888,
#      u'4': 0.14902222222222222,
#      u'5': 0.07511111111111111,
#      u'6': 0.05177777777777778}},
#    u'7': {u'centroids': {u'1': [0.4939552919708029,
#       0.6680411285794498,
#       0.9233605886206251],
#      u'2': [0.608703508709309, 0.7520048067770798, 0.9415705906148867],
#      u'3': [0.01168033359409924, 0.015374420261510952, 0.02273116199150648],
#      u'4': [0.3216969465193897, 0.5507526919103624, 0.8785163699936427],
#      u'5': [0.2916610054347826, 0.3237030632411067, 0.3755789896245059],
#      u'6': [0.7489911452394526, 0.8363227800741163, 0.961478673745724],
#      u'7': [0.6715621769112337, 1.0251984851206173, 1.5413986864024678]},
#     u'probs': {u'1': 0.23746666666666666,
#      u'2': 0.23346666666666666,
#      u'3': 0.19884444444444443,
#      u'4': 0.1398222222222222,
#      u'5': 0.11244444444444444,
#      u'6': 0.07795555555555556,
#      u'7': 0.0}},
#    u'maxk': 7},
#   u'collection': u'geotagged',
#   u'exif': {u'comments': {u'_content': u'6'},
#    u'dates': {u'lastupdate': u'1432145177',
#     u'posted': u'1432119600',
#     u'taken': u'2014-01-10 15:06:35',
#     u'takengranularity': u'0',
#     u'takenunknown': 0},
#    u'dateuploaded': u'1432119600',
#    u'description': {u'_content': u'No idea which way we are shown during a walk on the beach between Bloemendaal aan Zee and IJmuiden, as the plane above definitely knows its way around the sky.\n\nLens: Olympus M.Zuiko Digital 45mm F/1.8.'},
#    u'editability': {u'canaddmeta': 0, u'cancomment': 0},
#    u'farm': 6,
#    u'geoperms': {u'iscontact': 0,
#     u'isfamily': 0,
#     u'isfriend': 0,
#     u'ispublic': 1},
#    u'id': u'12130483536',
#    u'isfavorite': 0,
#    u'license': u'0',
#    u'location': {u'accuracy': u'12',
#     u'context': u'0',
#     u'country': {u'_content': u'Netherlands',
#      u'place_id': u'Exbw8apTUb6236fOVA',
#      u'woeid': u'23424909'},
#     u'county': {u'_content': u'Velsen',
#      u'place_id': u'qk6F1RpQUL9A1BwLWg',
#      u'woeid': u'12592444'},
#     u'latitude': u'52.431420',
#     u'locality': {u'_content': u'Santpoort-Zuid',
#      u'place_id': u'6gWTLj9WUbn_5u0',
#      u'woeid': u'733176'},
#     u'longitude': u'4.557437',
#     u'place_id': u'6gWTLj9WUbn_5u0',
#     u'region': {u'_content': u'North Holland',
#      u'place_id': u'F86XYCBTUb6DPzhs',
#      u'woeid': u'2346379'},
#     u'woeid': u'733176'},
#    u'media': u'photo',
#    u'notes': {u'note': []},
#    u'owner': {u'iconfarm': 9,
#     u'iconserver': u'8279',
#     u'location': u'The Netherlands',
#     u'nsid': u'61674778@N07',
#     u'path_alias': u'mattijsdiepraam',
#     u'realname': u'',
#     u'username': u'mdiepraam'},
#    u'people': {u'haspeople': 0},
#    u'publiceditability': {u'canaddmeta': 0, u'cancomment': 1},
#    u'rotation': 0,
#    u'safety_level': u'0',
#    u'secret': u'eeb0beb09f',
#    u'server': u'5500',
#    u'tags': {u'tag': [{u'_content': u'2014',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-265750',
#       u'machine_tag': 0,
#       u'raw': u'2014'},
#      {u'_content': u'beach',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-704',
#       u'machine_tag': 0,
#       u'raw': u'beach'},
#      {u'_content': u'bloemendaalaanzee',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-569607',
#       u'machine_tag': 0,
#       u'raw': u'bloemendaal aan zee'},
#      {u'_content': u'dutch',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-884',
#       u'machine_tag': 0,
#       u'raw': u'dutch'},
#      {u'_content': u'clouds',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-1223',
#       u'machine_tag': 0,
#       u'raw': u'clouds'},
#      {u'_content': u'sky',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-282',
#       u'machine_tag': 0,
#       u'raw': u'sky'},
#      {u'_content': u'pole',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-10946',
#       u'machine_tag': 0,
#       u'raw': u'pole'},
#      {u'_content': u'3',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-406',
#       u'machine_tag': 0,
#       u'raw': u'3'},
#      {u'_content': u'parnassia',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-1097099',
#       u'machine_tag': 0,
#       u'raw': u'parnassia'},
#      {u'_content': u'ijmuiden',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-326015',
#       u'machine_tag': 0,
#       u'raw': u'ijmuiden'}]},
#    u'title': {u'_content': u'Parnassia 2014: Numbers and directions'},
#    u'urls': {u'url': [{u'_content': u'https://www.flickr.com/photos/mattijsdiepraam/12130483536/',
#       u'type': u'photopage'}]},
#    u'usage': {u'canblog': 0,
#     u'candownload': 0,
#     u'canprint': 0,
#     u'canshare': 0},
#    u'views': u'3055',
#    u'visibility': {u'isfamily': 0, u'isfriend': 0, u'ispublic': 1}},
#   u'info': {u'comments': {u'_content': u'6'},
#    u'dates': {u'lastupdate': u'1432145177',
#     u'posted': u'1432119600',
#     u'taken': u'2014-01-10 15:06:35',
#     u'takengranularity': u'0',
#     u'takenunknown': 0},
#    u'dateuploaded': u'1432119600',
#    u'description': {u'_content': u'No idea which way we are shown during a walk on the beach between Bloemendaal aan Zee and IJmuiden, as the plane above definitely knows its way around the sky.\n\nLens: Olympus M.Zuiko Digital 45mm F/1.8.'},
#    u'editability': {u'canaddmeta': 0, u'cancomment': 0},
#    u'farm': 6,
#    u'geoperms': {u'iscontact': 0,
#     u'isfamily': 0,
#     u'isfriend': 0,
#     u'ispublic': 1},
#    u'id': u'12130483536',
#    u'isfavorite': 0,
#    u'license': u'0',
#    u'location': {u'accuracy': u'12',
#     u'context': u'0',
#     u'country': {u'_content': u'Netherlands',
#      u'place_id': u'Exbw8apTUb6236fOVA',
#      u'woeid': u'23424909'},
#     u'county': {u'_content': u'Velsen',
#      u'place_id': u'qk6F1RpQUL9A1BwLWg',
#      u'woeid': u'12592444'},
#     u'latitude': u'52.431420',
#     u'locality': {u'_content': u'Santpoort-Zuid',
#      u'place_id': u'6gWTLj9WUbn_5u0',
#      u'woeid': u'733176'},
#     u'longitude': u'4.557437',
#     u'place_id': u'6gWTLj9WUbn_5u0',
#     u'region': {u'_content': u'North Holland',
#      u'place_id': u'F86XYCBTUb6DPzhs',
#      u'woeid': u'2346379'},
#     u'woeid': u'733176'},
#    u'media': u'photo',
#    u'notes': {u'note': []},
#    u'owner': {u'iconfarm': 9,
#     u'iconserver': u'8279',
#     u'location': u'The Netherlands',
#     u'nsid': u'61674778@N07',
#     u'path_alias': u'mattijsdiepraam',
#     u'realname': u'',
#     u'username': u'mdiepraam'},
#    u'people': {u'haspeople': 0},
#    u'publiceditability': {u'canaddmeta': 0, u'cancomment': 1},
#    u'rotation': 0,
#    u'safety_level': u'0',
#    u'secret': u'eeb0beb09f',
#    u'server': u'5500',
#    u'tags': {u'tag': [{u'_content': u'2014',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-265750',
#       u'machine_tag': 0,
#       u'raw': u'2014'},
#      {u'_content': u'beach',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-704',
#       u'machine_tag': 0,
#       u'raw': u'beach'},
#      {u'_content': u'bloemendaalaanzee',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-569607',
#       u'machine_tag': 0,
#       u'raw': u'bloemendaal aan zee'},
#      {u'_content': u'dutch',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-884',
#       u'machine_tag': 0,
#       u'raw': u'dutch'},
#      {u'_content': u'clouds',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-1223',
#       u'machine_tag': 0,
#       u'raw': u'clouds'},
#      {u'_content': u'sky',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-282',
#       u'machine_tag': 0,
#       u'raw': u'sky'},
#      {u'_content': u'pole',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-10946',
#       u'machine_tag': 0,
#       u'raw': u'pole'},
#      {u'_content': u'3',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-406',
#       u'machine_tag': 0,
#       u'raw': u'3'},
#      {u'_content': u'parnassia',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-1097099',
#       u'machine_tag': 0,
#       u'raw': u'parnassia'},
#      {u'_content': u'ijmuiden',
#       u'author': u'61674778@N07',
#       u'authorname': u'mdiepraam',
#       u'id': u'61653448-12130483536-326015',
#       u'machine_tag': 0,
#       u'raw': u'ijmuiden'}]},
#    u'title': {u'_content': u'Parnassia 2014: Numbers and directions'},
#    u'urls': {u'url': [{u'_content': u'https://www.flickr.com/photos/mattijsdiepraam/12130483536/',
#       u'type': u'photopage'}]},
#    u'usage': {u'canblog': 0,
#     u'candownload': 0,
#     u'canprint': 0,
#     u'canshare': 0},
#    u'views': u'3055',
#    u'visibility': {u'isfamily': 0, u'isfriend': 0, u'ispublic': 1}},
#   u'photoid': u'12130483536',
#   u'secret': u'2015-06-20_16',
#   u'thumbh': 225,
#   u'thumbjpgbase64': u'...',
#   u'thumbw': 300}]

# %%
# For debugging
# datetimebin = 


import boto
s3 = boto.connect_s3()
bucket = s3.get_bucket(S3_BUCKET)

# %%
N = len(datetimebins)
for i,datetimebin in enumerate(datetimebins):
    print "################################################################################"
    print "Step (%d/%d): Creating _batchstage_counts/%s.p for " % (i+1, N, datetimebin)

    # If YYYY-MM-DD_HH.p has already been generated, no need to do it again.
    if bucket.get_key(os.path.join(collection,'_batchstage_counts',datetimebin+'.p','_SUCCESS')) is not None:
        print '--- File %s already exists. Skipping...' % (datetimebin+'.p')
        continue
        
    # Delete files that might prevent us from writing to YYYY-MM-DD_HH.p
    filestodelete = list(bucket.list(os.path.join(collection,'_batchstage_counts',datetimebin+'.p')))
    if len(filestodelete) > 0:
        print '--- Deleting:', filestodelete
        bucket.delete_keys(list(bucket.list(os.path.join(collection,'_batchstage_counts',datetimebin+'.p'))))

    try:
        rdd = sc.textFile(os.path.join(S3_PREFIX,'metaplus_%s.json'%(datetimebin)))
        rdd = rdd.map(lambda s: json.loads(s))
        rdd = rdd.flatMap(lambda d: (
                ######MONTHLY########
                    ((('country',LocationLevel(d, 'country')),
                                  ('region',LocationLevel(d, 'region')),
                                  ('county',LocationLevel(d, 'county')),
                                  ('locality',LocationLevel(d, 'locality')),
                                  ('datetaken',str(d['info']['dates']['taken'][:7])),
                                  ('granularity','locality/month'),
                                 ),1),

                    ((('country',LocationLevel(d, 'country')),
                                  ('region',LocationLevel(d, 'region')),
                                  ('county',LocationLevel(d, 'county')),
                                  ('locality','*'),
                                  ('datetaken',str(d['info']['dates']['taken'][:7])),
                                  ('granularity','county/month'),
                                 ),1),

                    ((('country',LocationLevel(d, 'country')),
                                  ('region',LocationLevel(d, 'region')),
                                  ('county','*'),
                                  ('locality','*'),
                                  ('datetaken',str(d['info']['dates']['taken'][:7])),
                                  ('granularity','region/month'),
                                 ),1),

                    ((('country',LocationLevel(d, 'country')),
                                  ('region','*'),
                                  ('county','*'),
                                  ('locality','*'),
                                  ('datetaken',str(d['info']['dates']['taken'][:7])),
                                  ('granularity','country/month'),
                                 ),1),

                    ((('country','*'),
                                  ('region','*'),
                                  ('county','*'),
                                  ('locality','*'),
                                  ('datetaken',str(d['info']['dates']['taken'][:7])),
                                  ('granularity','all/month'),
                                 ),1),

                ########YEARLY########
                    ((('country',LocationLevel(d, 'country')),
                                  ('region',LocationLevel(d, 'region')),
                                  ('county',LocationLevel(d, 'county')),
                                  ('locality',LocationLevel(d, 'locality')),
                                  ('datetaken',str(d['info']['dates']['taken'][:4])),
                                  ('granularity','locality/year'),
                                 ),1),

                    ((('country',LocationLevel(d, 'country')),
                                  ('region',LocationLevel(d, 'region')),
                                  ('county',LocationLevel(d, 'county')),
                                  ('locality','*'),
                                  ('datetaken',str(d['info']['dates']['taken'][:4])),
                                  ('granularity','county/year'),
                                 ),1),

                    ((('country',LocationLevel(d, 'country')),
                                  ('region',LocationLevel(d, 'region')),
                                  ('county','*'),
                                  ('locality','*'),
                                  ('datetaken',str(d['info']['dates']['taken'][:4])),
                                  ('granularity','region/year'),
                                 ),1),

                    ((('country',LocationLevel(d, 'country')),
                                  ('region','*'),
                                  ('county','*'),
                                  ('locality','*'),
                                  ('datetaken',str(d['info']['dates']['taken'][:4])),
                                  ('granularity','country/year'),
                                 ),1),

                    ((('country','*'),
                                  ('region','*'),
                                  ('county','*'),
                                  ('locality','*'),
                                  ('datetaken',str(d['info']['dates']['taken'][:4])),
                                  ('granularity','all/year'),
                                 ),1),
                ########ALL TIME########
                    ((('country',LocationLevel(d, 'country')),
                                  ('region',LocationLevel(d, 'region')),
                                  ('county',LocationLevel(d, 'county')),
                                  ('locality',LocationLevel(d, 'locality')),
                                  ('datetaken','*'),
                                  ('granularity','locality/all'),
                                 ),1),

                    ((('country',LocationLevel(d, 'country')),
                                  ('region',LocationLevel(d, 'region')),
                                  ('county',LocationLevel(d, 'county')),
                                  ('locality','*'),
                                  ('datetaken','*'),
                                  ('granularity','county/all'),
                                 ),1),

                    ((('country',LocationLevel(d, 'country')),
                                  ('region',LocationLevel(d, 'region')),
                                  ('county','*'),
                                  ('locality','*'),
                                  ('datetaken','*'),
                                  ('granularity','region/all'),
                                 ),1),

                    ((('country',LocationLevel(d, 'country')),
                                  ('region','*'),
                                  ('county','*'),
                                  ('locality','*'),
                                  ('datetaken','*'),
                                  ('granularity','country/all'),
                                 ),1),

                    ((('country','*'),
                                  ('region','*'),
                                  ('county','*'),
                                  ('locality','*'),
                                  ('datetaken','*'),
                                  ('granularity','all/all'),
                                 ),1),

                    ))
        rdd = rdd.reduceByKey(lambda x,y: x+y)
        rdd = rdd.coalesce(1)
        # %time rdd.saveAsPickleFile(os.path.join(S3_PREFIX,'_batchstage_counts',datetimebin+'.p'))
        print '--- Successfully wrote to '+datetimebin+'.p'
    except:
        print '--- DID NOT write to '+datetimebin+'.p'
# Out:
# ################################################################################
# Step (1/209): Creating _batchstage_counts/2015-06-20_16.p for
# --- File 2015-06-20_16.p already exists. Skipping...
# ################################################################################
# Step (2/209): Creating _batchstage_counts/2015-06-20_17.p for
# --- File 2015-06-20_17.p already exists. Skipping...
# ################################################################################
# Step (3/209): Creating _batchstage_counts/2015-06-20_18.p for
# --- File 2015-06-20_18.p already exists. Skipping...
# ################################################################################
# Step (4/209): Creating _batchstage_counts/2015-06-20_19.p for
# --- File 2015-06-20_19.p already exists. Skipping...
# ################################################################################
# Step (5/209): Creating _batchstage_counts/2015-06-20_20.p for
# --- File 2015-06-20_20.p already exists. Skipping...
# ################################################################################
# Step (6/209): Creating _batchstage_counts/2015-06-20_21.p for
# --- File 2015-06-20_21.p already exists. Skipping...
# ################################################################################
# Step (7/209): Creating _batchstage_counts/2015-06-20_22.p for
# --- File 2015-06-20_22.p already exists. Skipping...
# ################################################################################
# Step (8/209): Creating _batchstage_counts/2015-06-20_23.p for
# --- File 2015-06-20_23.p already exists. Skipping...
# ################################################################################
# Step (9/209): Creating _batchstage_counts/2015-06-21_00.p for
# --- File 2015-06-21_00.p already exists. Skipping...
# ################################################################################
# Step (10/209): Creating _batchstage_counts/2015-06-21_01.p for
# --- File 2015-06-21_01.p already exists. Skipping...
# ################################################################################
# Step (11/209): Creating _batchstage_counts/2015-06-21_02.p for
# --- File 2015-06-21_02.p already exists. Skipping...
# ################################################################################
# Step (12/209): Creating _batchstage_counts/2015-06-21_03.p for
# --- File 2015-06-21_03.p already exists. Skipping...
# ################################################################################
# Step (13/209): Creating _batchstage_counts/2015-06-21_04.p for
# --- File 2015-06-21_04.p already exists. Skipping...
# ################################################################################
# Step (14/209): Creating _batchstage_counts/2015-06-21_05.p for
# --- File 2015-06-21_05.p already exists. Skipping...
# ################################################################################
# Step (15/209): Creating _batchstage_counts/2015-06-21_06.p for
# --- File 2015-06-21_06.p already exists. Skipping...
# ################################################################################
# Step (16/209): Creating _batchstage_counts/2015-06-21_07.p for
# --- File 2015-06-21_07.p already exists. Skipping...
# ################################################################################
# Step (17/209): Creating _batchstage_counts/2015-06-21_08.p for
# --- File 2015-06-21_08.p already exists. Skipping...
# ################################################################################
# Step (18/209): Creating _batchstage_counts/2015-06-21_09.p for
# --- File 2015-06-21_09.p already exists. Skipping...
# ################################################################################
# Step (19/209): Creating _batchstage_counts/2015-06-21_10.p for
# --- File 2015-06-21_10.p already exists. Skipping...
# ################################################################################
# Step (20/209): Creating _batchstage_counts/2015-06-21_11.p for
# --- File 2015-06-21_11.p already exists. Skipping...
# ################################################################################
# Step (21/209): Creating _batchstage_counts/2015-06-21_12.p for
# --- File 2015-06-21_12.p already exists. Skipping...
# ################################################################################
# Step (22/209): Creating _batchstage_counts/2015-06-21_13.p for
# --- File 2015-06-21_13.p already exists. Skipping...
# ################################################################################
# Step (23/209): Creating _batchstage_counts/2015-06-21_14.p for
# --- File 2015-06-21_14.p already exists. Skipping...
# ################################################################################
# Step (24/209): Creating _batchstage_counts/2015-06-21_15.p for
# --- File 2015-06-21_15.p already exists. Skipping...
# ################################################################################
# Step (25/209): Creating _batchstage_counts/2015-06-21_16.p for
# --- File 2015-06-21_16.p already exists. Skipping...
# ################################################################################
# Step (26/209): Creating _batchstage_counts/2015-06-21_17.p for
# --- File 2015-06-21_17.p already exists. Skipping...
# ################################################################################
# Step (27/209): Creating _batchstage_counts/2015-06-21_18.p for
# --- File 2015-06-21_18.p already exists. Skipping...
# ################################################################################
# Step (28/209): Creating _batchstage_counts/2015-06-21_19.p for
# --- File 2015-06-21_19.p already exists. Skipping...
# ################################################################################
# Step (29/209): Creating _batchstage_counts/2015-06-21_20.p for
# --- File 2015-06-21_20.p already exists. Skipping...
# ################################################################################
# Step (30/209): Creating _batchstage_counts/2015-06-21_21.p for
# --- File 2015-06-21_21.p already exists. Skipping...
# ################################################################################
# Step (31/209): Creating _batchstage_counts/2015-06-21_22.p for
# --- File 2015-06-21_22.p already exists. Skipping...
# ################################################################################
# Step (32/209): Creating _batchstage_counts/2015-06-21_23.p for
# --- File 2015-06-21_23.p already exists. Skipping...
# ################################################################################
# Step (33/209): Creating _batchstage_counts/2015-06-22_00.p for
# --- File 2015-06-22_00.p already exists. Skipping...
# ################################################################################
# Step (34/209): Creating _batchstage_counts/2015-06-22_01.p for
# --- File 2015-06-22_01.p already exists. Skipping...
# ################################################################################
# Step (35/209): Creating _batchstage_counts/2015-06-22_02.p for
# --- File 2015-06-22_02.p already exists. Skipping...
# ################################################################################
# Step (36/209): Creating _batchstage_counts/2015-06-22_03.p for
# --- File 2015-06-22_03.p already exists. Skipping...
# ################################################################################
# Step (37/209): Creating _batchstage_counts/2015-06-22_04.p for
# --- File 2015-06-22_04.p already exists. Skipping...
# ################################################################################
# Step (38/209): Creating _batchstage_counts/2015-06-22_05.p for
# --- File 2015-06-22_05.p already exists. Skipping...
# ################################################################################
# Step (39/209): Creating _batchstage_counts/2015-06-22_06.p for
# --- File 2015-06-22_06.p already exists. Skipping...
# ################################################################################
# Step (40/209): Creating _batchstage_counts/2015-06-22_07.p for
# --- File 2015-06-22_07.p already exists. Skipping...
# ################################################################################
# Step (41/209): Creating _batchstage_counts/2015-06-22_08.p for
# --- File 2015-06-22_08.p already exists. Skipping...
# ################################################################################
# Step (42/209): Creating _batchstage_counts/2015-06-22_09.p for
# --- File 2015-06-22_09.p already exists. Skipping...
# ################################################################################
# Step (43/209): Creating _batchstage_counts/2015-06-22_10.p for
# --- File 2015-06-22_10.p already exists. Skipping...
# ################################################################################
# Step (44/209): Creating _batchstage_counts/2015-06-22_11.p for
# --- File 2015-06-22_11.p already exists. Skipping...
# ################################################################################
# Step (45/209): Creating _batchstage_counts/2015-06-22_12.p for
# --- File 2015-06-22_12.p already exists. Skipping...
# ################################################################################
# Step (46/209): Creating _batchstage_counts/2015-06-22_13.p for
# --- File 2015-06-22_13.p already exists. Skipping...
# ################################################################################
# Step (47/209): Creating _batchstage_counts/2015-06-22_14.p for
# --- File 2015-06-22_14.p already exists. Skipping...
# ################################################################################
# Step (48/209): Creating _batchstage_counts/2015-06-22_15.p for
# --- File 2015-06-22_15.p already exists. Skipping...
# ################################################################################
# Step (49/209): Creating _batchstage_counts/2015-06-22_16.p for
# --- File 2015-06-22_16.p already exists. Skipping...
# ################################################################################
# Step (50/209): Creating _batchstage_counts/2015-06-22_17.p for
# --- File 2015-06-22_17.p already exists. Skipping...
# ################################################################################
# Step (51/209): Creating _batchstage_counts/2015-06-22_18.p for
# --- File 2015-06-22_18.p already exists. Skipping...
# ################################################################################
# Step (52/209): Creating _batchstage_counts/2015-06-22_19.p for
# --- File 2015-06-22_19.p already exists. Skipping...
# ################################################################################
# Step (53/209): Creating _batchstage_counts/2015-06-22_20.p for
# --- File 2015-06-22_20.p already exists. Skipping...
# ################################################################################
# Step (54/209): Creating _batchstage_counts/2015-06-22_21.p for
# --- File 2015-06-22_21.p already exists. Skipping...
# ################################################################################
# Step (55/209): Creating _batchstage_counts/2015-06-22_22.p for
# --- File 2015-06-22_22.p already exists. Skipping...
# ################################################################################
# Step (56/209): Creating _batchstage_counts/2015-06-22_23.p for
# --- File 2015-06-22_23.p already exists. Skipping...
# ################################################################################
# Step (57/209): Creating _batchstage_counts/2015-06-23_00.p for
# --- DID NOT write to 2015-06-23_00.p
# ################################################################################
# Step (58/209): Creating _batchstage_counts/2015-06-23_01.p for
# --- DID NOT write to 2015-06-23_01.p
# ################################################################################
# Step (59/209): Creating _batchstage_counts/2015-06-23_02.p for
# --- DID NOT write to 2015-06-23_02.p
# ################################################################################
# Step (60/209): Creating _batchstage_counts/2015-06-23_03.p for
# --- DID NOT write to 2015-06-23_03.p
# ################################################################################
# Step (61/209): Creating _batchstage_counts/2015-06-23_04.p for
# --- DID NOT write to 2015-06-23_04.p
# ################################################################################
# Step (62/209): Creating _batchstage_counts/2015-06-23_05.p for
# --- DID NOT write to 2015-06-23_05.p
# ################################################################################
# Step (63/209): Creating _batchstage_counts/2015-06-23_06.p for
# --- DID NOT write to 2015-06-23_06.p
# ################################################################################
# Step (64/209): Creating _batchstage_counts/2015-06-23_07.p for
# --- DID NOT write to 2015-06-23_07.p
# ################################################################################
# Step (65/209): Creating _batchstage_counts/2015-06-23_08.p for
# --- File 2015-06-23_08.p already exists. Skipping...
# ################################################################################
# Step (66/209): Creating _batchstage_counts/2015-06-23_09.p for
# --- File 2015-06-23_09.p already exists. Skipping...
# ################################################################################
# Step (67/209): Creating _batchstage_counts/2015-06-23_10.p for
# --- File 2015-06-23_10.p already exists. Skipping...
# ################################################################################
# Step (68/209): Creating _batchstage_counts/2015-06-23_11.p for
# --- File 2015-06-23_11.p already exists. Skipping...
# ################################################################################
# Step (69/209): Creating _batchstage_counts/2015-06-23_12.p for
# --- File 2015-06-23_12.p already exists. Skipping...
# ################################################################################
# Step (70/209): Creating _batchstage_counts/2015-06-23_13.p for
# --- File 2015-06-23_13.p already exists. Skipping...
# ################################################################################
# Step (71/209): Creating _batchstage_counts/2015-06-23_14.p for
# --- File 2015-06-23_14.p already exists. Skipping...
# ################################################################################
# Step (72/209): Creating _batchstage_counts/2015-06-23_15.p for
# --- File 2015-06-23_15.p already exists. Skipping...
# ################################################################################
# Step (73/209): Creating _batchstage_counts/2015-06-23_16.p for
# --- File 2015-06-23_16.p already exists. Skipping...
# ################################################################################
# Step (74/209): Creating _batchstage_counts/2015-06-23_17.p for
# --- File 2015-06-23_17.p already exists. Skipping...
# ################################################################################
# Step (75/209): Creating _batchstage_counts/2015-06-23_18.p for
# --- File 2015-06-23_18.p already exists. Skipping...
# ################################################################################
# Step (76/209): Creating _batchstage_counts/2015-06-23_19.p for
# --- File 2015-06-23_19.p already exists. Skipping...
# ################################################################################
# Step (77/209): Creating _batchstage_counts/2015-06-23_20.p for
# --- File 2015-06-23_20.p already exists. Skipping...
# ################################################################################
# Step (78/209): Creating _batchstage_counts/2015-06-23_21.p for
# --- File 2015-06-23_21.p already exists. Skipping...
# ################################################################################
# Step (79/209): Creating _batchstage_counts/2015-06-23_22.p for
# --- File 2015-06-23_22.p already exists. Skipping...
# ################################################################################
# Step (80/209): Creating _batchstage_counts/2015-06-23_23.p for
# --- File 2015-06-23_23.p already exists. Skipping...
# ################################################################################
# Step (81/209): Creating _batchstage_counts/2015-06-24_00.p for
# --- File 2015-06-24_00.p already exists. Skipping...
# ################################################################################
# Step (82/209): Creating _batchstage_counts/2015-06-24_01.p for
# --- File 2015-06-24_01.p already exists. Skipping...
# ################################################################################
# Step (83/209): Creating _batchstage_counts/2015-06-24_02.p for
# --- File 2015-06-24_02.p already exists. Skipping...
# ################################################################################
# Step (84/209): Creating _batchstage_counts/2015-06-24_03.p for
# --- File 2015-06-24_03.p already exists. Skipping...
# ################################################################################
# Step (85/209): Creating _batchstage_counts/2015-06-24_04.p for
# --- File 2015-06-24_04.p already exists. Skipping...
# ################################################################################
# Step (86/209): Creating _batchstage_counts/2015-06-24_05.p for
# --- File 2015-06-24_05.p already exists. Skipping...
# ################################################################################
# Step (87/209): Creating _batchstage_counts/2015-06-24_06.p for
# --- File 2015-06-24_06.p already exists. Skipping...
# ################################################################################
# Step (88/209): Creating _batchstage_counts/2015-06-24_07.p for
# --- File 2015-06-24_07.p already exists. Skipping...
# ################################################################################
# Step (89/209): Creating _batchstage_counts/2015-06-24_08.p for
# --- File 2015-06-24_08.p already exists. Skipping...
# ################################################################################
# Step (90/209): Creating _batchstage_counts/2015-06-24_09.p for
# --- File 2015-06-24_09.p already exists. Skipping...
# ################################################################################
# Step (91/209): Creating _batchstage_counts/2015-06-24_10.p for
# --- File 2015-06-24_10.p already exists. Skipping...
# ################################################################################
# Step (92/209): Creating _batchstage_counts/2015-06-24_11.p for
# --- File 2015-06-24_11.p already exists. Skipping...
# ################################################################################
# Step (93/209): Creating _batchstage_counts/2015-06-24_12.p for
# --- File 2015-06-24_12.p already exists. Skipping...
# ################################################################################
# Step (94/209): Creating _batchstage_counts/2015-06-24_13.p for
# --- File 2015-06-24_13.p already exists. Skipping...
# ################################################################################
# Step (95/209): Creating _batchstage_counts/2015-06-24_14.p for
# --- File 2015-06-24_14.p already exists. Skipping...
# ################################################################################
# Step (96/209): Creating _batchstage_counts/2015-06-24_15.p for
# --- File 2015-06-24_15.p already exists. Skipping...
# ################################################################################
# Step (97/209): Creating _batchstage_counts/2015-06-24_16.p for
# --- File 2015-06-24_16.p already exists. Skipping...
# ################################################################################
# Step (98/209): Creating _batchstage_counts/2015-06-24_17.p for
# --- File 2015-06-24_17.p already exists. Skipping...
# ################################################################################
# Step (99/209): Creating _batchstage_counts/2015-06-24_18.p for
# --- File 2015-06-24_18.p already exists. Skipping...
# ################################################################################
# Step (100/209): Creating _batchstage_counts/2015-06-24_19.p for
# --- File 2015-06-24_19.p already exists. Skipping...
# ################################################################################
# Step (101/209): Creating _batchstage_counts/2015-06-24_20.p for
# --- File 2015-06-24_20.p already exists. Skipping...
# ################################################################################
# Step (102/209): Creating _batchstage_counts/2015-06-24_21.p for
# --- File 2015-06-24_21.p already exists. Skipping...
# ################################################################################
# Step (103/209): Creating _batchstage_counts/2015-06-24_22.p for
# --- File 2015-06-24_22.p already exists. Skipping...
# ################################################################################
# Step (104/209): Creating _batchstage_counts/2015-06-24_23.p for
# --- File 2015-06-24_23.p already exists. Skipping...
# ################################################################################
# Step (105/209): Creating _batchstage_counts/2015-06-25_00.p for
# --- File 2015-06-25_00.p already exists. Skipping...
# ################################################################################
# Step (106/209): Creating _batchstage_counts/2015-06-25_01.p for
# --- File 2015-06-25_01.p already exists. Skipping...
# ################################################################################
# Step (107/209): Creating _batchstage_counts/2015-06-25_02.p for
# --- File 2015-06-25_02.p already exists. Skipping...
# ################################################################################
# Step (108/209): Creating _batchstage_counts/2015-06-25_03.p for
# --- File 2015-06-25_03.p already exists. Skipping...
# ################################################################################
# Step (109/209): Creating _batchstage_counts/2015-06-25_04.p for
# --- File 2015-06-25_04.p already exists. Skipping...
# ################################################################################
# Step (110/209): Creating _batchstage_counts/2015-06-25_05.p for
# --- File 2015-06-25_05.p already exists. Skipping...
# ################################################################################
# Step (111/209): Creating _batchstage_counts/2015-06-25_06.p for
# --- File 2015-06-25_06.p already exists. Skipping...
# ################################################################################
# Step (112/209): Creating _batchstage_counts/2015-06-25_07.p for
# --- File 2015-06-25_07.p already exists. Skipping...
# ################################################################################
# Step (113/209): Creating _batchstage_counts/2015-06-25_08.p for
# --- File 2015-06-25_08.p already exists. Skipping...
# ################################################################################
# Step (114/209): Creating _batchstage_counts/2015-06-25_09.p for
# --- File 2015-06-25_09.p already exists. Skipping...
# ################################################################################
# Step (115/209): Creating _batchstage_counts/2015-06-25_10.p for
# --- File 2015-06-25_10.p already exists. Skipping...
# ################################################################################
# Step (116/209): Creating _batchstage_counts/2015-06-25_11.p for
# --- File 2015-06-25_11.p already exists. Skipping...
# ################################################################################
# Step (117/209): Creating _batchstage_counts/2015-06-25_12.p for
# --- File 2015-06-25_12.p already exists. Skipping...
# ################################################################################
# Step (118/209): Creating _batchstage_counts/2015-06-25_13.p for
# --- File 2015-06-25_13.p already exists. Skipping...
# ################################################################################
# Step (119/209): Creating _batchstage_counts/2015-06-25_14.p for
# --- File 2015-06-25_14.p already exists. Skipping...
# ################################################################################
# Step (120/209): Creating _batchstage_counts/2015-06-25_15.p for
# --- File 2015-06-25_15.p already exists. Skipping...
# ################################################################################
# Step (121/209): Creating _batchstage_counts/2015-06-25_16.p for
# --- File 2015-06-25_16.p already exists. Skipping...
# ################################################################################
# Step (122/209): Creating _batchstage_counts/2015-06-25_17.p for
# --- File 2015-06-25_17.p already exists. Skipping...
# ################################################################################
# Step (123/209): Creating _batchstage_counts/2015-06-25_18.p for
# --- File 2015-06-25_18.p already exists. Skipping...
# ################################################################################
# Step (124/209): Creating _batchstage_counts/2015-06-25_19.p for
# --- File 2015-06-25_19.p already exists. Skipping...
# ################################################################################
# Step (125/209): Creating _batchstage_counts/2015-06-25_20.p for
# --- File 2015-06-25_20.p already exists. Skipping...
# ################################################################################
# Step (126/209): Creating _batchstage_counts/2015-06-25_21.p for
# --- File 2015-06-25_21.p already exists. Skipping...
# ################################################################################
# Step (127/209): Creating _batchstage_counts/2015-06-25_22.p for
# --- File 2015-06-25_22.p already exists. Skipping...
# ################################################################################
# Step (128/209): Creating _batchstage_counts/2015-06-25_23.p for
# --- File 2015-06-25_23.p already exists. Skipping...
# ################################################################################
# Step (129/209): Creating _batchstage_counts/2015-06-26_00.p for
# --- File 2015-06-26_00.p already exists. Skipping...
# ################################################################################
# Step (130/209): Creating _batchstage_counts/2015-06-26_01.p for
# --- File 2015-06-26_01.p already exists. Skipping...
# ################################################################################
# Step (131/209): Creating _batchstage_counts/2015-06-26_02.p for
# --- File 2015-06-26_02.p already exists. Skipping...
# ################################################################################
# Step (132/209): Creating _batchstage_counts/2015-06-26_03.p for
# --- File 2015-06-26_03.p already exists. Skipping...
# ################################################################################
# Step (133/209): Creating _batchstage_counts/2015-06-26_04.p for
# --- File 2015-06-26_04.p already exists. Skipping...
# ################################################################################
# Step (134/209): Creating _batchstage_counts/2015-06-26_05.p for
# --- File 2015-06-26_05.p already exists. Skipping...
# ################################################################################
# Step (135/209): Creating _batchstage_counts/2015-06-26_06.p for
# --- File 2015-06-26_06.p already exists. Skipping...
# ################################################################################
# Step (136/209): Creating _batchstage_counts/2015-06-26_07.p for
# --- File 2015-06-26_07.p already exists. Skipping...
# ################################################################################
# Step (137/209): Creating _batchstage_counts/2015-06-26_08.p for
# --- File 2015-06-26_08.p already exists. Skipping...
# ################################################################################
# Step (138/209): Creating _batchstage_counts/2015-06-26_09.p for
# --- File 2015-06-26_09.p already exists. Skipping...
# ################################################################################
# Step (139/209): Creating _batchstage_counts/2015-06-26_10.p for
# --- File 2015-06-26_10.p already exists. Skipping...
# ################################################################################
# Step (140/209): Creating _batchstage_counts/2015-06-26_11.p for
# --- File 2015-06-26_11.p already exists. Skipping...
# ################################################################################
# Step (141/209): Creating _batchstage_counts/2015-06-26_12.p for
# --- File 2015-06-26_12.p already exists. Skipping...
# ################################################################################
# Step (142/209): Creating _batchstage_counts/2015-06-26_13.p for
# --- File 2015-06-26_13.p already exists. Skipping...
# ################################################################################
# Step (143/209): Creating _batchstage_counts/2015-06-26_14.p for
# --- File 2015-06-26_14.p already exists. Skipping...
# ################################################################################
# Step (144/209): Creating _batchstage_counts/2015-06-26_15.p for
# --- File 2015-06-26_15.p already exists. Skipping...
# ################################################################################
# Step (145/209): Creating _batchstage_counts/2015-06-26_16.p for
# --- File 2015-06-26_16.p already exists. Skipping...
# ################################################################################
# Step (146/209): Creating _batchstage_counts/2015-06-26_17.p for
# --- File 2015-06-26_17.p already exists. Skipping...
# ################################################################################
# Step (147/209): Creating _batchstage_counts/2015-06-26_18.p for
# --- File 2015-06-26_18.p already exists. Skipping...
# ################################################################################
# Step (148/209): Creating _batchstage_counts/2015-06-26_19.p for
# --- File 2015-06-26_19.p already exists. Skipping...
# ################################################################################
# Step (149/209): Creating _batchstage_counts/2015-06-26_20.p for
# --- File 2015-06-26_20.p already exists. Skipping...
# ################################################################################
# Step (150/209): Creating _batchstage_counts/2015-06-26_21.p for
# --- File 2015-06-26_21.p already exists. Skipping...
# ################################################################################
# Step (151/209): Creating _batchstage_counts/2015-06-26_22.p for
# --- File 2015-06-26_22.p already exists. Skipping...
# ################################################################################
# Step (152/209): Creating _batchstage_counts/2015-06-26_23.p for
# --- File 2015-06-26_23.p already exists. Skipping...
# ################################################################################
# Step (153/209): Creating _batchstage_counts/2015-06-27_00.p for
# --- File 2015-06-27_00.p already exists. Skipping...
# ################################################################################
# Step (154/209): Creating _batchstage_counts/2015-06-27_01.p for
# --- File 2015-06-27_01.p already exists. Skipping...
# ################################################################################
# Step (155/209): Creating _batchstage_counts/2015-06-27_02.p for
# --- File 2015-06-27_02.p already exists. Skipping...
# ################################################################################
# Step (156/209): Creating _batchstage_counts/2015-06-27_03.p for
# --- File 2015-06-27_03.p already exists. Skipping...
# ################################################################################
# Step (157/209): Creating _batchstage_counts/2015-06-27_04.p for
# --- DID NOT write to 2015-06-27_04.p
# ################################################################################
# Step (158/209): Creating _batchstage_counts/2015-06-27_05.p for
# --- DID NOT write to 2015-06-27_05.p
# ################################################################################
# Step (159/209): Creating _batchstage_counts/2015-06-27_06.p for
# --- DID NOT write to 2015-06-27_06.p
# ################################################################################
# Step (160/209): Creating _batchstage_counts/2015-06-27_07.p for
# --- DID NOT write to 2015-06-27_07.p
# ################################################################################
# Step (161/209): Creating _batchstage_counts/2015-06-27_08.p for
# --- DID NOT write to 2015-06-27_08.p
# ################################################################################
# Step (162/209): Creating _batchstage_counts/2015-06-27_09.p for
# --- DID NOT write to 2015-06-27_09.p
# ################################################################################
# Step (163/209): Creating _batchstage_counts/2015-06-27_10.p for
# --- DID NOT write to 2015-06-27_10.p
# ################################################################################
# Step (164/209): Creating _batchstage_counts/2015-06-27_11.p for
# --- DID NOT write to 2015-06-27_11.p
# ################################################################################
# Step (165/209): Creating _batchstage_counts/2015-06-27_12.p for
# --- DID NOT write to 2015-06-27_12.p
# ################################################################################
# Step (166/209): Creating _batchstage_counts/2015-06-27_13.p for
# --- DID NOT write to 2015-06-27_13.p
# ################################################################################
# Step (167/209): Creating _batchstage_counts/2015-06-27_14.p for
# --- DID NOT write to 2015-06-27_14.p
# ################################################################################
# Step (168/209): Creating _batchstage_counts/2015-06-27_15.p for
# --- DID NOT write to 2015-06-27_15.p
# ################################################################################
# Step (169/209): Creating _batchstage_counts/2015-06-27_16.p for
# --- DID NOT write to 2015-06-27_16.p
# ################################################################################
# Step (170/209): Creating _batchstage_counts/2015-06-27_17.p for
# --- DID NOT write to 2015-06-27_17.p
# ################################################################################
# Step (171/209): Creating _batchstage_counts/2015-06-27_18.p for
# --- DID NOT write to 2015-06-27_18.p
# ################################################################################
# Step (172/209): Creating _batchstage_counts/2015-06-27_19.p for
# --- DID NOT write to 2015-06-27_19.p
# ################################################################################
# Step (173/209): Creating _batchstage_counts/2015-06-27_20.p for
# --- DID NOT write to 2015-06-27_20.p
# ################################################################################
# Step (174/209): Creating _batchstage_counts/2015-06-27_21.p for
# --- DID NOT write to 2015-06-27_21.p
# ################################################################################
# Step (175/209): Creating _batchstage_counts/2015-06-27_22.p for
# --- DID NOT write to 2015-06-27_22.p
# ################################################################################
# Step (176/209): Creating _batchstage_counts/2015-06-27_23.p for
# --- DID NOT write to 2015-06-27_23.p
# ################################################################################
# Step (177/209): Creating _batchstage_counts/2015-06-28_00.p for
# --- DID NOT write to 2015-06-28_00.p
# ################################################################################
# Step (178/209): Creating _batchstage_counts/2015-06-28_01.p for
# --- DID NOT write to 2015-06-28_01.p
# ################################################################################
# Step (179/209): Creating _batchstage_counts/2015-06-28_02.p for
# --- DID NOT write to 2015-06-28_02.p
# ################################################################################
# Step (180/209): Creating _batchstage_counts/2015-06-28_03.p for
# --- DID NOT write to 2015-06-28_03.p
# ################################################################################
# Step (181/209): Creating _batchstage_counts/2015-06-28_04.p for
# --- DID NOT write to 2015-06-28_04.p
# ################################################################################
# Step (182/209): Creating _batchstage_counts/2015-06-28_05.p for
# --- DID NOT write to 2015-06-28_05.p
# ################################################################################
# Step (183/209): Creating _batchstage_counts/2015-06-28_06.p for
# --- DID NOT write to 2015-06-28_06.p
# ################################################################################
# Step (184/209): Creating _batchstage_counts/2015-06-28_07.p for
# --- DID NOT write to 2015-06-28_07.p
# ################################################################################
# Step (185/209): Creating _batchstage_counts/2015-06-28_08.p for
# --- DID NOT write to 2015-06-28_08.p
# ################################################################################
# Step (186/209): Creating _batchstage_counts/2015-06-28_09.p for
# --- DID NOT write to 2015-06-28_09.p
# ################################################################################
# Step (187/209): Creating _batchstage_counts/2015-06-28_10.p for
# --- DID NOT write to 2015-06-28_10.p
# ################################################################################
# Step (188/209): Creating _batchstage_counts/2015-06-28_11.p for
# --- DID NOT write to 2015-06-28_11.p
# ################################################################################
# Step (189/209): Creating _batchstage_counts/2015-06-28_12.p for
# --- DID NOT write to 2015-06-28_12.p
# ################################################################################
# Step (190/209): Creating _batchstage_counts/2015-06-28_13.p for
# --- DID NOT write to 2015-06-28_13.p
# ################################################################################
# Step (191/209): Creating _batchstage_counts/2015-06-28_14.p for
# --- DID NOT write to 2015-06-28_14.p
# ################################################################################
# Step (192/209): Creating _batchstage_counts/2015-06-28_15.p for
# --- DID NOT write to 2015-06-28_15.p
# ################################################################################
# Step (193/209): Creating _batchstage_counts/2015-06-28_16.p for
# --- DID NOT write to 2015-06-28_16.p
# ################################################################################
# Step (194/209): Creating _batchstage_counts/2015-06-28_17.p for
# --- DID NOT write to 2015-06-28_17.p
# ################################################################################
# Step (195/209): Creating _batchstage_counts/2015-06-28_18.p for
# --- DID NOT write to 2015-06-28_18.p
# ################################################################################
# Step (196/209): Creating _batchstage_counts/2015-06-28_19.p for
# --- DID NOT write to 2015-06-28_19.p
# ################################################################################
# Step (197/209): Creating _batchstage_counts/2015-06-28_20.p for
# --- DID NOT write to 2015-06-28_20.p
# ################################################################################
# Step (198/209): Creating _batchstage_counts/2015-06-28_21.p for
# --- DID NOT write to 2015-06-28_21.p
# ################################################################################
# Step (199/209): Creating _batchstage_counts/2015-06-28_22.p for
# --- DID NOT write to 2015-06-28_22.p
# ################################################################################
# Step (200/209): Creating _batchstage_counts/2015-06-28_23.p for
# --- DID NOT write to 2015-06-28_23.p
# ################################################################################
# Step (201/209): Creating _batchstage_counts/2015-06-29_00.p for
# --- DID NOT write to 2015-06-29_00.p
# ################################################################################
# Step (202/209): Creating _batchstage_counts/2015-06-29_01.p for
# --- DID NOT write to 2015-06-29_01.p
# ################################################################################
# Step (203/209): Creating _batchstage_counts/2015-06-29_02.p for
# --- DID NOT write to 2015-06-29_02.p
# ################################################################################
# Step (204/209): Creating _batchstage_counts/2015-06-29_03.p for
# --- DID NOT write to 2015-06-29_03.p
# ################################################################################
# Step (205/209): Creating _batchstage_counts/2015-06-29_04.p for
# --- DID NOT write to 2015-06-29_04.p
# ################################################################################
# Step (206/209): Creating _batchstage_counts/2015-06-29_05.p for
# --- DID NOT write to 2015-06-29_05.p
# ################################################################################
# Step (207/209): Creating _batchstage_counts/2015-06-29_06.p for
# --- DID NOT write to 2015-06-29_06.p
# ################################################################################
# Step (208/209): Creating _batchstage_counts/2015-06-29_07.p for
# --- DID NOT write to 2015-06-29_07.p
# ################################################################################
# Step (209/209): Creating _batchstage_counts/2015-06-29_08.p for
# --- DID NOT write to 2015-06-29_08.p

# %%
# Each hour's bin produces a pickle file that is <2MB. For a year that isn't bad (~18GB)
# If this poses a problem in the future, previous days can always be grouped by day
# and months by month, etc.
rdd = sc.pickleFile(os.path.join(S3_PREFIX,'_batchstage_counts','*'))

# %%
rdd = rdd.reduceByKey(lambda x,y: x+y)
rdd = rdd.map(lambda tup: dict(count=tup[1],**{item[0]:item[1] for item in tup[0]}))

# %%
rdd.persist()
# Out:
# PythonRDD[189] at RDD at PythonRDD.scala:42

# %%
def AddToCassandra_allcountsbatch_bypartition(d_iter):
    from cqlengine import columns
    from cqlengine.models import Model
    from cqlengine import connection
    from cqlengine.management import sync_table
    
    class allcountsbatch(Model):
        granularity = columns.Text(primary_key=True)
        country = columns.Text(primary_key=True)
        region = columns.Text(primary_key=True)
        county = columns.Text(primary_key=True)
        locality = columns.Text(primary_key=True)
        datetaken = columns.Text(primary_key=True)
        count = columns.Integer()
        
    connection.setup(['127.0.0.1'], CASSANDRA_KEYSPACE)

    sync_table(allcountsbatch)

    for d in d_iter:
        allcountsbatch.create(**d)

# Create table if it does not exist. Need to do this before submitting to Spark to avoid collisions
AddToCassandra_allcountsbatch_bypartition([])

# %%
rdd.foreachPartition(AddToCassandra_allcountsbatch_bypartition)
