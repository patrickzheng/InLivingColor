# %% [markdown]
# # Load Spark

# %%
################################################################################
# LOAD SPARK

import os
import sys

spark_home = os.environ.get('SPARK_HOME', None)
if not spark_home:
    raise ValueError('SPARK_HOME environment variable is not set')
sys.path.insert(0, os.path.join(spark_home, 'python'))
sys.path.insert(0, os.path.join(spark_home, 'python/lib/py4j-0.8.2.1-src.zip'))
os.environ['PYSPARK_SUBMIT_ARGS'] = "--num-executors 4 --master yarn --deploy-mode client"

execfile(os.path.join(spark_home, 'python/pyspark/shell.py'))
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 1.3.0
#       /_/
#
# Using Python version 2.7.9 (default, Mar  9 2015 16:20:48)
# SparkContext available as sc, HiveContext available as sqlCtx.

# %%
################################################################################
# LOAD NEEDED MODULES AND FUNCTIONS

from _configuration import *
from datetime import datetime
import time
import calendar
from math import ceil
import json

import boto
s3 = boto.connect_s3()
bucket = s3.get_bucket(S3_BUCKET)

from elasticsearch import Elasticsearch
es = Elasticsearch() # by default we connect to localhost:9200


def WriteToElasticSearch_bypartition(index, doc_type, kv_iter):
    """
    This preserves keys. Unlike elasticsearch-hadoop-2.1.0.jar .
    # print testrdd.saveAsNewAPIHadoopFile(
    #     path='-', 
    #     outputFormatClass="org.elasticsearch.hadoop.mr.EsOutputFormat",
    #     keyClass="org.apache.hadoop.io.NullWritable", 
    #     valueClass="org.elasticsearch.hadoop.mr.LinkedMapWritable", 
    #     conf={ "es.resource" : "test/test3" })
    """
    from elasticsearch import Elasticsearch
    es = Elasticsearch()
    
    for kv in kv_iter:
        _id = kv[0]
        body = kv[1]

        es.index(index=index,doc_type=doc_type, id=_id, body=body)

# %%
def GetLastDownloadTimestamp(index='inlivingcolor', doc_type='colorcluster'):

    rsp = es.search(index=index, doc_type=doc_type, body="""
    {
      "fields" : ["_id","downloadtimestamp"],
      "query": {
        "match_all": {}
      },
      "size": "1",
      "sort": [
        {
          "downloadtimestamp": {
            "order": "desc"
          }
        }
      ]

    };""")
    return str(rsp['hits']['hits'][0]['fields']['downloadtimestamp'][0])

# GetLastDownloadTimestamp()

# %%
# print datetimebins
# print '2015-06-20_16'
# print str(GetLastDownloadTimestamp

try:
    startatthistime = time.mktime(time.strptime(GetLastDownloadTimestamp(),"%Y-%m-%d_%H")) - 3600*24
except:
    startatthistime = FIRSTBINEVER
        

datetimebins = map(lambda d: time.strftime('%Y-%m-%d_%H', time.gmtime(d)), range(int(startatthistime),int(time.time()),3600))
print datetimebins
# len([str(GetLastDownloadTimestamp()) < bin for bin in datetimebins])
# Out:
# WARNING:elasticsearch:GET /inlivingcolor/colorcluster/_search [status:404 request:0.002s]
# ['2015-06-20_16', '2015-06-20_17', '2015-06-20_18', '2015-06-20_19', '2015-06-20_20', '2015-06-20_21', '2015-06-20_22', '2015-06-20_23', '2015-06-21_00', '2015-06-21_01', '2015-06-21_02', '2015-06-21_03', '2015-06-21_04', '2015-06-21_05', '2015-06-21_06', '2015-06-21_07', '2015-06-21_08', '2015-06-21_09', '2015-06-21_10', '2015-06-21_11', '2015-06-21_12', '2015-06-21_13', '2015-06-21_14', '2015-06-21_15', '2015-06-21_16', '2015-06-21_17', '2015-06-21_18', '2015-06-21_19', '2015-06-21_20', '2015-06-21_21', '2015-06-21_22', '2015-06-21_23', '2015-06-22_00', '2015-06-22_01', '2015-06-22_02', '2015-06-22_03', '2015-06-22_04', '2015-06-22_05', '2015-06-22_06', '2015-06-22_07', '2015-06-22_08', '2015-06-22_09', '2015-06-22_10', '2015-06-22_11', '2015-06-22_12', '2015-06-22_13', '2015-06-22_14', '2015-06-22_15', '2015-06-22_16', '2015-06-22_17', '2015-06-22_18', '2015-06-22_19', '2015-06-22_20', '2015-06-22_21', '2015-06-22_22', '2015-06-22_23', '2015-06-23_00', '2015-06-23_01', '2015-06-23_02', '2015-06-23_03', '2015-06-23_04', '2015-06-23_05', '2015-06-23_06', '2015-06-23_07', '2015-06-23_08', '2015-06-23_09', '2015-06-23_10', '2015-06-23_11', '2015-06-23_12', '2015-06-23_13', '2015-06-23_14', '2015-06-23_15', '2015-06-23_16', '2015-06-23_17', '2015-06-23_18', '2015-06-23_19', '2015-06-23_20', '2015-06-23_21', '2015-06-23_22', '2015-06-23_23', '2015-06-24_00', '2015-06-24_01', '2015-06-24_02', '2015-06-24_03', '2015-06-24_04', '2015-06-24_05', '2015-06-24_06', '2015-06-24_07', '2015-06-24_08', '2015-06-24_09', '2015-06-24_10', '2015-06-24_11', '2015-06-24_12', '2015-06-24_13', '2015-06-24_14', '2015-06-24_15', '2015-06-24_16', '2015-06-24_17', '2015-06-24_18', '2015-06-24_19', '2015-06-24_20', '2015-06-24_21', '2015-06-24_22', '2015-06-24_23', '2015-06-25_00', '2015-06-25_01', '2015-06-25_02', '2015-06-25_03', '2015-06-25_04', '2015-06-25_05', '2015-06-25_06', '2015-06-25_07', '2015-06-25_08', '2015-06-25_09', '2015-06-25_10', '2015-06-25_11', '2015-06-25_12', '2015-06-25_13', '2015-06-25_14', '2015-06-25_15', '2015-06-25_16', '2015-06-25_17', '2015-06-25_18', '2015-06-25_19', '2015-06-25_20', '2015-06-25_21', '2015-06-25_22', '2015-06-25_23', '2015-06-26_00', '2015-06-26_01', '2015-06-26_02', '2015-06-26_03', '2015-06-26_04', '2015-06-26_05', '2015-06-26_06', '2015-06-26_07', '2015-06-26_08', '2015-06-26_09', '2015-06-26_10', '2015-06-26_11', '2015-06-26_12', '2015-06-26_13', '2015-06-26_14', '2015-06-26_15', '2015-06-26_16', '2015-06-26_17', '2015-06-26_18', '2015-06-26_19', '2015-06-26_20', '2015-06-26_21', '2015-06-26_22', '2015-06-26_23', '2015-06-27_00', '2015-06-27_01', '2015-06-27_02', '2015-06-27_03', '2015-06-27_04', '2015-06-27_05', '2015-06-27_06', '2015-06-27_07', '2015-06-27_08', '2015-06-27_09', '2015-06-27_10', '2015-06-27_11', '2015-06-27_12', '2015-06-27_13', '2015-06-27_14', '2015-06-27_15', '2015-06-27_16', '2015-06-27_17', '2015-06-27_18', '2015-06-27_19', '2015-06-27_20', '2015-06-27_21', '2015-06-27_22', '2015-06-27_23', '2015-06-28_00', '2015-06-28_01', '2015-06-28_02', '2015-06-28_03', '2015-06-28_04', '2015-06-28_05', '2015-06-28_06', '2015-06-28_07', '2015-06-28_08', '2015-06-28_09', '2015-06-28_10', '2015-06-28_11', '2015-06-28_12', '2015-06-28_13', '2015-06-28_14', '2015-06-28_15', '2015-06-28_16', '2015-06-28_17', '2015-06-28_18', '2015-06-28_19', '2015-06-28_20', '2015-06-28_21', '2015-06-28_22', '2015-06-28_23', '2015-06-29_00', '2015-06-29_01', '2015-06-29_02', '2015-06-29_03', '2015-06-29_04', '2015-06-29_05', '2015-06-29_06', '2015-06-29_07', '2015-06-29_08', '2015-06-29_09', '2015-06-29_10', '2015-06-29_11', '2015-06-29_12', '2015-06-29_13', '2015-06-29_14', '2015-06-29_15', '2015-06-29_16', '2015-06-29_17', '2015-06-29_18', '2015-06-29_19', '2015-06-29_20', '2015-06-29_21', '2015-06-29_22', '2015-06-29_23', '2015-06-30_00', '2015-06-30_01', '2015-06-30_02', '2015-06-30_03', '2015-06-30_04', '2015-06-30_05', '2015-06-30_06', '2015-06-30_07', '2015-06-30_08', '2015-06-30_09', '2015-06-30_10', '201 ...

# %%
maps = []
maps.append(['collection', lambda d: (d['collection']),None])
maps.append(['datetaken', lambda d: (d['info']['dates']['taken'][:10]),None])
maps.append(['photoid', lambda d: (d['photoid']),None])
# maps.append(['_id', lambda d: (d['photoid']),None])

maps.append(['tags', lambda d: ' '.join([i['_content'] for i in d['info']['tags']['tag']]),''])

maps.append(['latitude', lambda d: float(d['info']['location']['latitude']),None])
maps.append(['longitude', lambda d: float(d['info']['location']['longitude']),None])

maps.append(['country', lambda d: (d['info']['location']['country']['_content']) ,'_'])
maps.append(['region', lambda d: (d['info']['location']['region']['_content']) ,'_'])
maps.append(['county', lambda d: (d['info']['location']['county']['_content']) ,'_'])
maps.append(['locality', lambda d: (d['info']['location']['locality']['_content']) ,'_'])

maps.append(['url', lambda d: str(d['info']['urls']['url'][0]['_content']), ''])
maps.append(['thumbh', lambda d: int(d['thumbh']), None])
maps.append(['thumbw', lambda d: int(d['thumbw']), None])

maps.append(['downloadtimestamp', lambda d: d['secret'], None])


# # this crazy function gives a good guess for k
maps.append(['goodk',lambda d: (np.array([min(pdist([v for k,v in (d['clusters']['%d'%i]['centroids']).iteritems()])) for i in range(2,6)])>.25).sum()+1,3])

maps.append(['c1c1r',lambda d: int(d['clusters']['1']['centroids']['1'][0]*256),None])
maps.append(['c1c1g',lambda d: int(d['clusters']['1']['centroids']['1'][1]*256),None])
maps.append(['c1c1b',lambda d: int(d['clusters']['1']['centroids']['1'][2]*256),None])
maps.append(['c1p1',lambda d: int(d['clusters']['1']['probs']['1']*100),None])
maps.append(['c2c1r',lambda d: int(d['clusters']['2']['centroids']['1'][0]*256),None])
maps.append(['c2c1g',lambda d: int(d['clusters']['2']['centroids']['1'][1]*256),None])
maps.append(['c2c1b',lambda d: int(d['clusters']['2']['centroids']['1'][2]*256),None])
maps.append(['c2p1',lambda d: int(d['clusters']['2']['probs']['1']*100),None])
maps.append(['c2c2r',lambda d: int(d['clusters']['2']['centroids']['2'][0]*256),None])
maps.append(['c2c2g',lambda d: int(d['clusters']['2']['centroids']['2'][1]*256),None])
maps.append(['c2c2b',lambda d: int(d['clusters']['2']['centroids']['2'][2]*256),None])
maps.append(['c2p2',lambda d: int(d['clusters']['2']['probs']['2']*100),None])
maps.append(['c3c1r',lambda d: int(d['clusters']['3']['centroids']['1'][0]*256),None])
maps.append(['c3c1g',lambda d: int(d['clusters']['3']['centroids']['1'][1]*256),None])
maps.append(['c3c1b',lambda d: int(d['clusters']['3']['centroids']['1'][2]*256),None])
maps.append(['c3p1',lambda d: int(d['clusters']['3']['probs']['1']*100),None])
maps.append(['c3c2r',lambda d: int(d['clusters']['3']['centroids']['2'][0]*256),None])
maps.append(['c3c2g',lambda d: int(d['clusters']['3']['centroids']['2'][1]*256),None])
maps.append(['c3c2b',lambda d: int(d['clusters']['3']['centroids']['2'][2]*256),None])
maps.append(['c3p2',lambda d: int(d['clusters']['3']['probs']['2']*100),None])
maps.append(['c3c3r',lambda d: int(d['clusters']['3']['centroids']['3'][0]*256),None])
maps.append(['c3c3g',lambda d: int(d['clusters']['3']['centroids']['3'][1]*256),None])
maps.append(['c3c3b',lambda d: int(d['clusters']['3']['centroids']['3'][2]*256),None])
maps.append(['c3p3',lambda d: int(d['clusters']['3']['probs']['3']*100),None])
maps.append(['c4c1r',lambda d: int(d['clusters']['4']['centroids']['1'][0]*256),None])
maps.append(['c4c1g',lambda d: int(d['clusters']['4']['centroids']['1'][1]*256),None])
maps.append(['c4c1b',lambda d: int(d['clusters']['4']['centroids']['1'][2]*256),None])
maps.append(['c4p1',lambda d: int(d['clusters']['4']['probs']['1']*100),None])
maps.append(['c4c2r',lambda d: int(d['clusters']['4']['centroids']['2'][0]*256),None])
maps.append(['c4c2g',lambda d: int(d['clusters']['4']['centroids']['2'][1]*256),None])
maps.append(['c4c2b',lambda d: int(d['clusters']['4']['centroids']['2'][2]*256),None])
maps.append(['c4p2',lambda d: int(d['clusters']['4']['probs']['2']*100),None])
maps.append(['c4c3r',lambda d: int(d['clusters']['4']['centroids']['3'][0]*256),None])
maps.append(['c4c3g',lambda d: int(d['clusters']['4']['centroids']['3'][1]*256),None])
maps.append(['c4c3b',lambda d: int(d['clusters']['4']['centroids']['3'][2]*256),None])
maps.append(['c4p3',lambda d: int(d['clusters']['4']['probs']['3']*100),None])
maps.append(['c4c4r',lambda d: int(d['clusters']['4']['centroids']['4'][0]*256),None])
maps.append(['c4c4g',lambda d: int(d['clusters']['4']['centroids']['4'][1]*256),None])
maps.append(['c4c4b',lambda d: int(d['clusters']['4']['centroids']['4'][2]*256),None])
maps.append(['c4p4',lambda d: int(d['clusters']['4']['probs']['4']*100),None])
maps.append(['c5c1r',lambda d: int(d['clusters']['5']['centroids']['1'][0]*256),None])
maps.append(['c5c1g',lambda d: int(d['clusters']['5']['centroids']['1'][1]*256),None])
maps.append(['c5c1b',lambda d: int(d['clusters']['5']['centroids']['1'][2]*256),None])
maps.append(['c5p1',lambda d: int(d['clusters']['5']['probs']['1']*100),None])
maps.append(['c5c2r',lambda d: int(d['clusters']['5']['centroids']['2'][0]*256),None])
maps.append(['c5c2g',lambda d: int(d['clusters']['5']['centroids']['2'][1]*256),None])
maps.append(['c5c2b',lambda d: int(d['clusters']['5']['centroids']['2'][2]*256),None])
maps.append(['c5p2',lambda d: int(d['clusters']['5']['probs']['2']*100),None])
maps.append(['c5c3r',lambda d: int(d['clusters']['5']['centroids']['3'][0]*256),None])
maps.append(['c5c3g',lambda d: int(d['clusters']['5']['centroids']['3'][1]*256),None])
maps.append(['c5c3b',lambda d: int(d['clusters']['5']['centroids']['3'][2]*256),None])
maps.append(['c5p3',lambda d: int(d['clusters']['5']['probs']['3']*100),None])
maps.append(['c5c4r',lambda d: int(d['clusters']['5']['centroids']['4'][0]*256),None])
maps.append(['c5c4g',lambda d: int(d['clusters']['5']['centroids']['4'][1]*256),None])
maps.append(['c5c4b',lambda d: int(d['clusters']['5']['centroids']['4'][2]*256),None])
maps.append(['c5p4',lambda d: int(d['clusters']['5']['probs']['4']*100),None])
maps.append(['c5c5r',lambda d: int(d['clusters']['5']['centroids']['5'][0]*256),None])
maps.append(['c5c5g',lambda d: int(d['clusters']['5']['centroids']['5'][1]*256),None])
maps.append(['c5c5b',lambda d: int(d['clusters']['5']['centroids']['5'][2]*256),None])
maps.append(['c5p5',lambda d: int(d['clusters']['5']['probs']['5']*100),None])

             
# Use the following to generate the above
# for i in range(1,6):
#     for j in range(1,i+1):
#         print "maps.append(['c%dc%dr',lambda d: int(d['clusters']['%d']['centroids']['%d'][0]*256),None])"%(i,j,i,j)
#         print "maps.append(['c%dc%dg',lambda d: int(d['clusters']['%d']['centroids']['%d'][1]*256),None])"%(i,j,i,j)
#         print "maps.append(['c%dc%db',lambda d: int(d['clusters']['%d']['centroids']['%d'][2]*256),None])"%(i,j,i,j)
#         print "maps.append(['c%dp%d',lambda d: int(d['clusters']['%d']['probs']['%d']*100),None])"%(i,j,i,j)


def simplifyrecord(d):
    output = {}
    
    for m in maps:
        try:
            output[m[0]] = m[1](d)
        except:
            if m[2] is None:
                return None
            else:
                output[m[0]] = m[2]
    
    return output

# %%
def batch_movetoelasticsearch(collection=None,datetimebins=[], dry_run=True):

    print '------------------------------------------------------------------------'
    print 'Moving Color Clustering data to Elastic Search'
    print ''

    for datetimebinstr in datetimebins:
        print datetimebinstr
        
        try:
            # Load JSON files form S3 and convert to Python dict's
            rdd = sc.textFile(os.path.join(S3_PREFIX,'metaplus_%s.json'%datetimebinstr))
            rdd = rdd.map(lambda s: json.loads(s))

            # Simplify for ElasticSearch, remove erroneous entries, and place in key-value form
            rdd = rdd.map(simplifyrecord).filter(lambda d: d is not None).map(lambda d: (d['photoid'],d))

            # Write to ElasticSearch partition by partition
            # %time rdd.foreachPartition(lambda kv_iter: WriteToElasticSearch_bypartition('inlivingcolor','colorcluster',kv_iter))
        except:
            print "Error: Perhaps %s does not exist?" % ('metaplus_%s.json'%datetimebinstr)
            

batch_movetoelasticsearch(collection=collection,datetimebins=datetimebins[:])
# Out:
# ------------------------------------------------------------------------
# Moving Color Clustering data to Elastic Search
#
# 2015-06-20_16
# CPU times: user 23.9 ms, sys: 399 µs, total: 24.3 ms
# Wall time: 17 s
# 2015-06-20_17
# CPU times: user 22.5 ms, sys: 22 µs, total: 22.5 ms
# Wall time: 13.8 s
# 2015-06-20_18
# CPU times: user 20.6 ms, sys: 0 ns, total: 20.6 ms
# Wall time: 9.92 s
# 2015-06-20_19
# CPU times: user 20.9 ms, sys: 13 µs, total: 20.9 ms
# Wall time: 9.79 s
# 2015-06-20_20
# CPU times: user 21.5 ms, sys: 4.4 ms, total: 25.9 ms
# Wall time: 9.09 s
# 2015-06-20_21
# CPU times: user 21.2 ms, sys: 23 µs, total: 21.2 ms
# Wall time: 11.3 s
# 2015-06-20_22
# CPU times: user 20.7 ms, sys: 214 µs, total: 20.9 ms
# Wall time: 8.73 s
# 2015-06-20_23
# CPU times: user 21.6 ms, sys: 168 µs, total: 21.7 ms
# Wall time: 9.41 s
# 2015-06-21_00
# CPU times: user 22.4 ms, sys: 79 µs, total: 22.5 ms
# Wall time: 9.2 s
# 2015-06-21_01
# CPU times: user 25.7 ms, sys: 196 µs, total: 25.9 ms
# Wall time: 9.21 s
# 2015-06-21_02
# CPU times: user 21.1 ms, sys: 8 µs, total: 21.1 ms
# Wall time: 8.88 s
# 2015-06-21_03
# CPU times: user 26.4 ms, sys: 183 µs, total: 26.6 ms
# Wall time: 8.64 s
# 2015-06-21_04
# CPU times: user 22.1 ms, sys: 209 µs, total: 22.3 ms
# Wall time: 8.2 s
# 2015-06-21_05
# CPU times: user 22.1 ms, sys: 0 ns, total: 22.1 ms
# Wall time: 8.05 s
# 2015-06-21_06
# CPU times: user 20.6 ms, sys: 141 µs, total: 20.7 ms
# Wall time: 8.05 s
# 2015-06-21_07
# CPU times: user 21.2 ms, sys: 0 ns, total: 21.2 ms
# Wall time: 7.73 s
# 2015-06-21_08
# CPU times: user 18.4 ms, sys: 270 µs, total: 18.6 ms
# Wall time: 7.64 s
# 2015-06-21_09
# CPU times: user 21.7 ms, sys: 30 µs, total: 21.8 ms
# Wall time: 7.45 s
# 2015-06-21_10
# CPU times: user 27.6 ms, sys: 0 ns, total: 27.6 ms
# Wall time: 8.2 s
# 2015-06-21_11
# CPU times: user 22.6 ms, sys: 0 ns, total: 22.6 ms
# Wall time: 7.76 s
# 2015-06-21_12
# CPU times: user 22.1 ms, sys: 0 ns, total: 22.1 ms
# Wall time: 8.04 s
# 2015-06-21_13
# CPU times: user 21 ms, sys: 0 ns, total: 21 ms
# Wall time: 7.49 s
# 2015-06-21_14
# CPU times: user 20.9 ms, sys: 0 ns, total: 20.9 ms
# Wall time: 7.56 s
# 2015-06-21_15
# CPU times: user 21 ms, sys: 6 µs, total: 21 ms
# Wall time: 7.62 s
# 2015-06-21_16
# CPU times: user 16.6 ms, sys: 4.03 ms, total: 20.6 ms
# Wall time: 7.65 s
# 2015-06-21_17
# CPU times: user 26.2 ms, sys: 430 µs, total: 26.6 ms
# Wall time: 11.2 s
# 2015-06-21_18
# CPU times: user 21.6 ms, sys: 137 µs, total: 21.8 ms
# Wall time: 11.4 s
# 2015-06-21_19
# CPU times: user 20.7 ms, sys: 47 µs, total: 20.7 ms
# Wall time: 12.1 s
# 2015-06-21_20
# CPU times: user 38.5 ms, sys: 13 µs, total: 38.5 ms
# Wall time: 11.1 s
# 2015-06-21_21
# CPU times: user 23.1 ms, sys: 0 ns, total: 23.1 ms
# Wall time: 11.2 s
# 2015-06-21_22
# CPU times: user 21.5 ms, sys: 0 ns, total: 21.5 ms
# Wall time: 11.5 s
# 2015-06-21_23
# CPU times: user 21.8 ms, sys: 0 ns, total: 21.8 ms
# Wall time: 11.4 s
# 2015-06-22_00
# CPU times: user 28.7 ms, sys: 0 ns, total: 28.7 ms
# Wall time: 11.5 s
# 2015-06-22_01
# CPU times: user 21.8 ms, sys: 0 ns, total: 21.8 ms
# Wall time: 11.6 s
# 2015-06-22_02
# CPU times: user 22.8 ms, sys: 0 ns, total: 22.8 ms
# Wall time: 11.4 s
# 2015-06-22_03
# CPU times: user 21.7 ms, sys: 0 ns, total: 21.7 ms
# Wall time: 11.3 s
# 2015-06-22_04
# CPU times: user 23.3 ms, sys: 0 ns, total: 23.3 ms
# Wall time: 10.7 s
# 2015-06-22_05
# CPU times: user 21.8 ms, sys: 0 ns, total: 21.8 ms
# Wall time: 10.8 s
# 2015-06-22_06
# CPU times: user 22.3 ms, sys: 0 ns, total: 22.3 ms
# Wall time: 9.41 s
# 2015-06-22_07
# CPU times: user 28.3 ms, sys: 267 µs, total: 28.5 ms
# Wall time: 10.4 s
# 2015-06-22_08
# CPU times: user 21 ms, sys: 102 µs, total: 21.1 ms
# Wall time: 9.6 s
# 2015-06-22_09
# CPU times: user 21.4 ms, sys: 12 µs, total: 21.4 ms
# Wall time: 8.93 s
# 2015-06-22_10
# CPU times: user 22 ms, sys: 25 µs, total: 22 ms
# Wall time: 9.31 s
# 2015-06-22_11
# CPU times: user 20.7 ms, sys: 148 µs, total: 20.9 ms
# Wall time: 9.14 s
# 2015-06-22_12
# CPU times: user 20.8 ms, sys: 0 ns, total: 20.8 ms
# Wall time: 8.83 s
# 2015-06-22_13
# CPU times: user 38.2 ms, sys: 0 ns, total: 38.2 ms
# Wall time: 7.95 s
# 2015-06-22_14
# CPU times: user 28.1 ms, sys: 8 µs, total: 28.1 ms
# Wall time: 9.3 s
# 2015-06-22_15
# CPU times: user 21.5 ms, sys: 105 µs, total: 21.6 ms
# Wall time: 10.3 s
# 2015-06-22_16
# CPU times: user 21.6 ms, sys: 4 µs, total: 21.6 ms
# Wall time: 9.9 s
# 2015-06-22_17
# CPU times: user 21.3 ms, sys: 163 µs, total: 21.5 ms
# Wall time: 10.1 s
# 2015-06-22_18
# CPU times: user 22.1 ms, sys: 0 ns, total: 22.1 ms
# Wall time: 10.8 s
# 2015-06-22_19
# CPU times: user 24.8 ms, sys: 0 ns, total: 24.8 ms
# Wall time: 11.7 s
# 2015-06-22_20
# CPU times: user 21.4 ms, sys: 35 µs, total: 21.4 ms
# Wall time: 9.8 s
# 2015-06-22_21
# CPU times: user 23.1 ms, sys: 4.36 ms, total: 27.4 ms
# Wall time: 7.33 s
# 2015-06-22_22
# CPU times: user 22.3 ms, sys: 0 ns, total: 22.3 ms
# Wall time: 11.4 s
# 2015-06-22_23
# CPU times: user 19.7 ms, sys: 0 ns, total: 19.7 ms
# Wall time: 2.98 s
# 2015-06-23_00
# Error: Perhaps metaplus_2015-06-23_00.json does not exist?
# 2015-06-23_01
# Error: Perhaps metaplus_2015-06-23_01.json does not exist?
# 2015-06-23_02
# Error: Perhaps metaplus_2015-06-23_02.json does not exist?
# 2015-06-23_03
# Error: Perhaps metaplus_2015-06-23_03.json does not exist?
# 2015-06-23_04
# Error: Perhaps metaplus_2015-06-23_04.json does not exist?
# 2015-06-23_05
# Error: Perhaps metaplus_2015-06-23_05.json does not exist?
# 2015-06-23_06
# Error: Perhaps metaplus_2015-06-23_06.json does not exist?
# 2015-06-23_07
# Error: Perhaps metaplus_2015-06-23_07.json does not exist?
# 2015-06-23_08
# CPU times: user 21.3 ms, sys: 0 ns, total: 21.3 ms
# Wall time: 8.09 s
# 2015-06-23_09
# CPU times: user 22.5 ms, sys: 0 ns, total: 22.5 ms
# Wall time: 11 s
# 2015-06-23_10
# CPU times: user 28.1 ms, sys: 0 ns, total: 28.1 ms
# Wall time: 12.4 s
# 2015-06-23_11
# CPU times: user 22.2 ms, sys: 0 ns, total: 22.2 ms
# Wall time: 11.3 s
# 2015-06-23_12
# CPU times: user 23.7 ms, sys: 0 ns, total: 23.7 ms
# Wall time: 10.7 s
# 2015-06-23_13
# CPU times: user 22 ms, sys: 0 ns, total: 22 ms
# Wall time: 11.5 s
# 2015-06-23_14
# CPU times: user 17.6 ms, sys: 4.02 ms, total: 21.6 ms
# Wall time: 11.1 s
# 2015-06-23_15
# CPU times: user 22.1 ms, sys: 22 µs, total: 22.2 ms
# Wall time: 11.8 s
# 2015-06-23_16
# CPU times: user 18.6 ms, sys: 4.2 ms, total: 22.8 ms
# Wall time: 11.8 s
# 2015-06-23_17
# CPU times: user 22.3 ms, sys: 4.68 ms, total: 27 ms
# Wall time: 11.6 s
# 2015-06-23_18
# CPU times: user 23.7 ms, sys: 0 ns, total: 23.7 ms
# Wall time: 11.5 s
# 2015-06-23_19
# CPU times: user 21.6 ms, sys: 4 µs, total: 21.6 ms
# Wall time: 11 s
# 2015-06-23_20
# CPU times: user 21.8 ms, sys: 112 µs, total: 21.9 ms
# Wall time: 11.1 s
# 2015-06-23_21
# CPU times: user 22.1 ms, sys: 0 ns, total: 22.1 ms
# Wall time: 11.1 s
# 2015-06-23_22
# CPU times: user 20.6 ms, sys: 197 µs, total: 20.8 ms
# Wall time: 11 s
# 2015-06-23_23
# CPU times: user 21.9 ms, sys: 13 µs, total: 22 ms
# Wall time: 11.1 s
# 2015-06-24_00
# CPU times: user 47.8 ms, sys: 312 µs, total: 48.1 ms
# Wall time: 11.6 s
# 2015-06-24_01
# CPU times: user 18 ms, sys: 4.19 ms, total: 22.2 ms
# Wall time: 11.3 s
# 2015-06-24_02
# CPU times: user 34.7 ms, sys: 4.3 ms, total: 39 ms
# Wall time: 10.9 s
# 2015-06-24_03
# CPU times: user 21.9 ms, sys: 184 µs, total: 22.1 ms
# Wall time: 11.3 s
# 2015-06-24_04
# CPU times: user 23 ms, sys: 0 ns, total: 23 ms
# Wall time: 11.1 s
# 2015-06-24_05
# CPU times: user 34.8 ms, sys: 0 ns, total: 34.8 ms
# Wall time: 13.1 s
# 2015-06-24_06
# CPU times: user 21.8 ms, sys: 172 µs, total: 21.9 ms
# Wall time: 11.3 s
# 2015-06-24_07
# CPU times: user 28.9 ms, sys: 42 µs, total: 28.9 ms
# Wall time: 11.7 s
# 2015-06-24_08
# CPU times: user 22.9 ms, sys: 158 µs, total: 23.1 ms
# Wall time: 11.6 s
# 2015-06-24_09
# CPU times: user 21.9 ms, sys: 4 µs, total: 21.9 ms
# Wall time: 11.7 s
# 2015-06-24_10
# CPU times: user 22 ms, sys: 0 ns, total: 22 ms
# Wall time: 11.5 s
# 2015-06-24_11
# CPU times: user 23.7 ms, sys: 0 ns, total: 23.7 ms
# Wall time: 11.3 s
# 2015-06-24_12
# CPU times: user 21.9 ms, sys: 58 µs, total: 21.9 ms
# Wall time: 11.1 s
# 2015-06-24_13
# CPU times: user 24.1 ms, sys: 24 µs, total: 24.1 ms
# Wall time: 11.7 s
# 2015-06-24_14
# CPU times: user 30.4 ms, sys: 160 µs, total: 30.6 ms
# Wall time: 10.9 s
# 2015-06-24_15
# CPU times: user 21.8 ms, sys: 0 ns, total: 21.8 ms
# Wall time: 11.2 s
# 2015-06-24_16
# CPU times: user 22.3 ms, sys: 180 µs, total: 22.5 ms
# Wall time: 11.4 s
# 2015-06-24_17
# CPU times: user 20.6 ms, sys: 4.33 ms, total: 25 ms
# Wall time: 11 s
# 2015-06-24_18
# CPU times: user 17.9 ms, sys: 4.31 ms, total: 22.2 ms
# Wall time: 10.9 s
# 2015-06-24_19
# CPU times: user 24.3 ms, sys: 93 µs, total: 24.4 ms
# Wall time: 11.3 s
# 2015-06-24_20
# CPU times: user 22.5 ms, sys: 0 ns, total: 22.5 ms
# Wall time: 11.3 s
# 2015-06-24_21
# CPU times: user 28.2 ms, sys: 129 µs, total: 28.3 ms
# Wall time: 10.8 s
# 2015-06-24_22
# CPU times: user 21.6 ms, sys: 0 ns, total: 21.6 ms
# Wall time: 10.2 s
# 2015-06-24_23
# CPU times: user 21.9 ms, sys: 0 ns, total: 21.9 ms
# Wall time: 10.5 s
# 2015-06-25_00
# CPU times: user 21.6 ms, sys: 150 µs, total: 21.7 ms
# Wall time: 10.5 s
# 2015-06-25_01
# CPU times: user 21.6 ms, sys: 151 µs, total: 21.8 ms
# Wall time: 10.8 s
# 2015-06-25_02
# CPU times: user 21.4 ms, sys: 0 ns, total: 21.4 ms
# Wall time: 11.2 s
# 2015-06-25_03
# CPU times: user 21.5 ms, sys: 0 ns, total: 21.5 ms
# Wall time: 11 s
# 2015-06-25_04
# CPU times: user 28.4 ms, sys: 75 µs, total: 28.5 ms
# Wall time: 10.4 s
# 2015-06-25_05
# CPU times: user 22.5 ms, sys: 0 ns, total: 22.5 ms
# Wall time: 10.8 s
# 2015-06-25_06
# CPU times: user 21.6 ms, sys: 0 ns, total: 21.6 ms
# Wall time: 11.2 s
# 2015-06-25_07
# CPU times: user 22.7 ms, sys: 0 ns, total: 22.7 ms
# Wall time: 10.4 s
# 2015-06-25_08
# CPU times: user 21.7 ms, sys: 0 ns, total: 21.7 ms
# Wall time: 12 s
# 2015-06-25_09
# CPU times: user 21.9 ms, sys: 153 µs, total: 22 ms
# Wall time: 10.6 s
# 2015-06-25_10
# CPU times: user 21 ms, sys: 0 ns, total: 21 ms
# Wall time: 7.39 s
# 2015-06-25_11
# CPU times: user 27.7 ms, sys: 95 µs, total: 27.8 ms
# Wall time: 10.8 s
# 2015-06-25_12
# CPU times: user 21.8 ms, sys: 0 ns, total: 21.8 ms
# Wall time: 10.5 s
# 2015-06-25_13
# CPU times: user 21.9 ms, sys: 8 µs, total: 21.9 ms
# Wall time: 11.5 s
# 2015-06-25_14
# CPU times: user 38.9 ms, sys: 0 ns, total: 38.9 ms
# Wall time: 10.8 s
# 2015-06-25_15
# CPU times: user 21.9 ms, sys: 0 ns, total: 21.9 ms
# Wall time: 11.6 s
# 2015-06-25_16
# CPU times: user 21.6 ms, sys: 122 µs, total: 21.7 ms
# Wall time: 11 s
# 2015-06-25_17
# CPU times: user 19.8 ms, sys: 73 µs, total: 19.9 ms
# Wall time: 3.53 s
# 2015-06-25_18
# CPU times: user 24.1 ms, sys: 4.18 ms, total: 28.3 ms
# Wall time: 7.27 s
# 2015-06-25_19
# CPU times: user 22.3 ms, sys: 0 ns, total: 22.3 ms
# Wall time: 10.6 s
# 2015-06-25_20
# CPU times: user 38.9 ms, sys: 0 ns, total: 38.9 ms
# Wall time: 10.7 s
# 2015-06-25_21
# CPU times: user 20.6 ms, sys: 0 ns, total: 20.6 ms
# Wall time: 6.43 s
# 2015-06-25_22
# CPU times: user 22.8 ms, sys: 0 ns, total: 22.8 ms
# Wall time: 11.2 s
# 2015-06-25_23
# CPU times: user 22 ms, sys: 0 ns, total: 22 ms
# Wall time: 11.6 s
# 2015-06-26_00
# CPU times: user 22.3 ms, sys: 0 ns, total: 22.3 ms
# Wall time: 10.9 s
# 2015-06-26_01
# CPU times: user 28.7 ms, sys: 0 ns, total: 28.7 ms
# Wall time: 10.5 s
# 2015-06-26_02
# CPU times: user 21.8 ms, sys: 122 µs, total: 21.9 ms
# Wall time: 10.9 s
# 2015-06-26_03
# CPU times: user 22.2 ms, sys: 0 ns, total: 22.2 ms
# Wall time: 11.7 s
# 2015-06-26_04
# CPU times: user 22 ms, sys: 0 ns, total: 22 ms
# Wall time: 11.4 s
# 2015-06-26_05
# CPU times: user 23.2 ms, sys: 36 µs, total: 23.2 ms
# Wall time: 11 s
# 2015-06-26_06
# CPU times: user 20.5 ms, sys: 92 µs, total: 20.6 ms
# Wall time: 6.53 s
# 2015-06-26_07
# CPU times: user 22.2 ms, sys: 0 ns, total: 22.2 ms
# Wall time: 11.4 s
# 2015-06-26_08
# CPU times: user 30.1 ms, sys: 0 ns, total: 30.1 ms
# Wall time: 11.8 s
# 2015-06-26_09
# CPU times: user 21.9 ms, sys: 0 ns, total: 21.9 ms
# Wall time: 11.7 s
# 2015-06-26_10
# CPU times: user 21.6 ms, sys: 0 ns, total: 21.6 ms
# Wall time: 11 s
# 2015-06-26_11
# CPU times: user 22.3 ms, sys: 0 ns, total: 22.3 ms
# Wall time: 11.3 s
# 2015-06-26_12
# CPU times: user 23.8 ms, sys: 0 ns, total: 23.8 ms
# Wall time: 11.5 s
# 2015-06-26_13
# CPU times: user 21.7 ms, sys: 0 ns, total: 21.7 ms
# Wall time: 11.4 s
# 2015-06-26_14
# CPU times: user 22.2 ms, sys: 0 ns, total: 22.2 ms
# Wall time: 11.7 s
# 2015-06-26_15
# CPU times: user 30.7 ms, sys: 0 ns, total: 30.7 ms
# Wall time: 11.4 s
# 2015-06-26_16
# CPU times: user 22.1 ms, sys: 55 µs, total: 22.2 ms
# Wall time: 11.7 s
# 2015-06-26_17
# CPU times: user 22 ms, sys: 1 µs, total: 22 ms
# Wall time: 11.6 s
# 2015-06-26_18
# CPU times: user 22.3 ms, sys: 142 µs, total: 22.4 ms
# Wall time: 11 s
# 2015-06-26_19
# CPU times: user 39.7 ms, sys: 0 ns, total: 39.7 ms
# Wall time: 11.2 s
# 2015-06-26_20
# CPU times: user 23.1 ms, sys: 0 ns, total: 23.1 ms
# Wall time: 11.2 s
# 2015-06-26_21
# CPU times: user 22.3 ms, sys: 0 ns, total: 22.3 ms
# Wall time: 11.7 s
# 2015-06-26_22
# CPU times: user 37.5 ms, sys: 4.21 ms, total: 41.7 ms
# Wall time: 4.84 s
# 2015-06-26_23
# CPU times: user 23.3 ms, sys: 0 ns, total: 23.3 ms
# Wall time: 11.3 s
# 2015-06-27_00
# CPU times: user 22 ms, sys: 0 ns, total: 22 ms
# Wall time: 11.1 s
# 2015-06-27_01
# CPU times: user 18.2 ms, sys: 4.45 ms, total: 22.6 ms
# Wall time: 11.9 s
# 2015-06-27_02
# CPU times: user 23.2 ms, sys: 38 µs, total: 23.2 ms
# Wall time: 11.2 s
# 2015-06-27_03
# CPU times: user 21.9 ms, sys: 131 µs, total: 22 ms
# Wall time: 11.4 s
# 2015-06-27_04
# CPU times: user 23.9 ms, sys: 4.64 ms, total: 28.5 ms
# Wall time: 11.5 s
# 2015-06-27_05
# CPU times: user 23.1 ms, sys: 4.33 ms, total: 27.4 ms
# Wall time: 11.6 s
# 2015-06-27_06
# CPU times: user 22.8 ms, sys: 20 µs, total: 22.9 ms
# Wall time: 11.3 s
# 2015-06-27_07
# CPU times: user 23.3 ms, sys: 33 µs, total: 23.3 ms
# Wall time: 11.6 s
# 2015-06-27_08
# CPU times: user 17.9 ms, sys: 4.16 ms, total: 22 ms
# Wall time: 11.4 s
# 2015-06-27_09
# CPU times: user 22.2 ms, sys: 0 ns, total: 22.2 ms
# Wall time: 11.3 s
# 2015-06-27_10
# CPU times: user 22.4 ms, sys: 0 ns, total: 22.4 ms
# Wall time: 11.6 s
# 2015-06-27_11
# CPU times: user 22.4 ms, sys: 4 µs, total: 22.4 ms
# Wall time: 11.3 s
# 2015-06-27_12
# CPU times: user 42.9 ms, sys: 4.37 ms, total: 47.2 ms
# Wall time: 11.5 s
# 2015-06-27_13
# CPU times: user 20.7 ms, sys: 13 µs, total: 20.7 ms
# Wall time: 11.4 s
# 2015-06-27_14
# CPU times: user 21.8 ms, sys: 133 µs, total: 21.9 ms
# Wall time: 11.8 s
# 2015-06-27_15
# CPU times: user 22.4 ms, sys: 0 ns, total: 22.4 ms
# Wall time: 11 s
# 2015-06-27_16
# CPU times: user 23.1 ms, sys: 0 ns, total: 23.1 ms
# Wall time: 11.1 s
# 2015-06-27_17
# CPU times: user 21.8 ms, sys: 133 µs, total: 21.9 ms
# Wall time: 11.9 s
# 2015-06-27_18
# CPU times: user 39.4 ms, sys: 0 ns, total: 39.4 ms
# Wall time: 10.9 s
# 2015-06-27_19
# CPU times: user 29.2 ms, sys: 0 ns, total: 29.2 ms
# Wall time: 11.6 s
# 2015-06-27_20
# CPU times: user 24.3 ms, sys: 65 µs, total: 24.4 ms
# Wall time: 11.1 s
# 2015-06-27_21
# CPU times: user 23.3 ms, sys: 0 ns, total: 23.3 ms
# Wall time: 11.1 s
# 2015-06-27_22
# CPU times: user 21.9 ms, sys: 48 µs, total: 22 ms
# Wall time: 11.1 s
# 2015-06-27_23
# CPU times: user 22.8 ms, sys: 15 µs, total: 22.8 ms
# Wall time: 10.8 s
# 2015-06-28_00
# CPU times: user 21.9 ms, sys: 0 ns, total: 21.9 ms
# Wall time: 11.2 s
# 2015-06-28_01
# CPU times: user 22.3 ms, sys: 0 ns, total: 22.3 ms
# Wall time: 11 s
# 2015-06-28_02
# CPU times: user 28 ms, sys: 0 ns, total: 28 ms
# Wall time: 11.3 s
# 2015-06-28_03
# CPU times: user 22.1 ms, sys: 53 µs, total: 22.2 ms
# Wall time: 11.2 s
# 2015-06-28_04
# CPU times: user 22 ms, sys: 0 ns, total: 22 ms
# Wall time: 12 s
# 2015-06-28_05
# CPU times: user 22.2 ms, sys: 67 µs, total: 22.3 ms
# Wall time: 11.3 s
# 2015-06-28_06
# CPU times: user 18.4 ms, sys: 4.21 ms, total: 22.6 ms
# Wall time: 11.2 s
# 2015-06-28_07
# CPU times: user 23.2 ms, sys: 171 µs, total: 23.4 ms
# Wall time: 18.8 s
# 2015-06-28_08
# CPU times: user 22.2 ms, sys: 4.55 ms, total: 26.8 ms
# Wall time: 27.4 s
# 2015-06-28_09
# CPU times: user 33.1 ms, sys: 57 µs, total: 33.1 ms
# Wall time: 27.5 s
# 2015-06-28_10
# CPU times: user 26.8 ms, sys: 228 µs, total: 27 ms
# Wall time: 29.1 s
# 2015-06-28_11
# CPU times: user 25.8 ms, sys: 255 µs, total: 26.1 ms
# Wall time: 28 s
# 2015-06-28_12
# CPU times: user 26 ms, sys: 260 µs, total: 26.3 ms
# Wall time: 27 s
# 2015-06-28_13
# CPU times: user 20.1 ms, sys: 139 µs, total: 20.3 ms
# Wall time: 28.3 s
# 2015-06-28_14
# CPU times: user 26.3 ms, sys: 60 µs, total: 26.3 ms
# Wall time: 27.4 s
# 2015-06-28_15
# CPU times: user 28.3 ms, sys: 0 ns, total: 28.3 ms
# Wall time: 27.8 s
# 2015-06-28_16
# CPU times: user 32.3 ms, sys: 245 µs, total: 32.5 ms
# Wall time: 28.3 s
# 2015-06-28_17
# CPU times: user 26.1 ms, sys: 0 ns, total: 26.1 ms
# Wall time: 29.4 s
# 2015-06-28_18
# CPU times: user 26.5 ms, sys: 184 µs, total: 26.7 ms
# Wall time: 28.2 s
# 2015-06-28_19
# CPU times: user 26.1 ms, sys: 118 µs, total: 26.2 ms
# Wall time: 28.9 s
# 2015-06-28_20
# CPU times: user 38 ms, sys: 4.35 ms, total: 42.3 ms
# Wall time: 29 s
# 2015-06-28_21
# CPU times: user 26 ms, sys: 202 µs, total: 26.2 ms
# Wall time: 28.3 s
# 2015-06-28_22
# CPU times: user 25.5 ms, sys: 30 µs, total: 25.5 ms
# Wall time: 26.7 s
# 2015-06-28_23
# CPU times: user 30.8 ms, sys: 62 µs, total: 30.8 ms
# Wall time: 26.2 s
# 2015-06-29_00
# CPU times: user 25 ms, sys: 164 µs, total: 25.2 ms
# Wall time: 25.2 s
# 2015-06-29_01
# CPU times: user 17.3 ms, sys: 8.85 ms, total: 26.1 ms
# Wall time: 24.7 s
# 2015-06-29_02
# CPU times: user 26.1 ms, sys: 55 µs, total: 26.2 ms
# Wall time: 24.6 s
# 2015-06-29_03
# CPU times: user 25.4 ms, sys: 0 ns, total: 25.4 ms
# Wall time: 25.2 s
# 2015-06-29_04
# CPU times: user 22.3 ms, sys: 4.38 ms, total: 26.7 ms
# Wall time: 24.1 s
# 2015-06-29_05
# Error: Perhaps metaplus_2015-06-29_05.json does not exist?
# 2015-06-29_06
# Error: Perhaps metaplus_2015-06-29_06.json does not exist?
# 2015-06-29_07
# Error: Perhaps metaplus_2015-06-29_07.json does not exist?
# 2015-06-29_08
# Error: Perhaps metaplus_2015-06-29_08.json does not exist?
# 2015-06-29_09
# Error: Perhaps metaplus_2015-06-29_09.json does not exist?
# 2015-06-29_10
# Error: Perhaps metaplus_2015-06-29_10.json does not exist?
# 2015-06-29_11
# Error: Perhaps metaplus_2015-06-29_11.json does not exist?
# 2015-06-29_12
# Error: Perhaps metaplus_2015-06-29_12.json does not exist?
# 2015-06-29_13
# Error: Perhaps metaplus_2015-06-29_13.json does not exist?
# 2015-06-29_14
# Error: Perhaps metaplus_2015-06-29_14.json does not exist?
# 2015-06-29_15
# Error: Perhaps metaplus_2015-06-29_15.json does not exist?
# 2015-06-29_16
# Error: Perhaps metaplus_2015-06-29_16.json does not exist?
# 2015-06-29_17
# Error: Perhaps metaplus_2015-06-29_17.json does not exist?
# 2015-06-29_18
# Error: Perhaps metaplus_2015-06-29_18.json does not exist?
# 2015-06-29_19
# Error: Perhaps metaplus_2015-06-29_19.json does not exist?
# 2015-06-29_20
# Error: Perhaps metaplus_2015-06-29_20.json does not exist?
# 2015-06-29_21
# Error: Perhaps metaplus_2015-06-29_21.json does not exist?
# 2015-06-29_22
# Error: Perhaps metaplus_2015-06-29_22.json does not exist?
# 2015-06-29_23
# Error: Perhaps metaplus_2015-06-29_23.json does not exist?
# 2015-06-30_00
# Error: Perhaps metaplus_2015-06-30_00.json does not exist?
# 2015-06-30_01
# Error: Perhaps metaplus_2015-06-30_01.json does not exist?
# 2015-06-30_02
# Error: Perhaps metaplus_2015-06-30_02.json does not exist?
# 2015-06-30_03
# Error: Perhaps metaplus_2015-06-30_03.json does not exist?
# 2015-06-30_04
# Error: Perhaps metaplus_2015-06-30_04.json does not exist?
# 2015-06-30_05
# Error: Perhaps metaplus_2015-06-30_05.json does not exist?
# 2015-06-30_06
# Error: Perhaps metaplus_2015-06-30_06.json does not exist?
# 2015-06-30_07
# Error: Perhaps metaplus_2015-06-30_07.json does not exist?
# 2015-06-30_08
# Error: Perhaps metaplus_2015-06-30_08.json does not exist?
# 2015-06-30_09
# Error: Perhaps metaplus_2015-06-30_09.json does not exist?
# 2015-06-30_10
# Error: Perhaps metaplus_2015-06-30_10.json does not exist?
# 2015-06-30_11
# Error: Perhaps metaplus_2015-06-30_11.json does not exist?
# 2015-06-30_12
# Error: Perhaps metaplus_2015-06-30_12.json does not exist?
# 2015-06-30_13
# Error: Perhaps metaplus_2015-06-30_13.json does not exist?
# 2015-06-30_14
# Error: Perhaps metaplus_2015-06-30_14.json does not exist?
# 2015-06-30_15
# Error: Perhaps metaplus_2015-06-30_15.json does not exist?
# 2015-06-30_16
# Error: Perhaps metaplus_2015-06-30_16.json does not exist?
# 2015-06-30_17
# Error: Perhaps metaplus_2015-06-30_17.json does not exist?
# 2015-06-30_18
# Error: Perhaps metaplus_2015-06-30_18.json does not exist?
# 2015-06-30_19
# Error: Perhaps metaplus_2015-06-30_19.json does not exist?
# 2015-06-30_20
# Error: Perhaps metaplus_2015-06-30_20.json does not exist?
# 2015-06-30_21
# Error: Perhaps metaplus_2015-06-30_21.json does not exist?
# 2015-06-30_22
# Error: Perhaps metaplus_2015-06-30_22.json does not exist?
